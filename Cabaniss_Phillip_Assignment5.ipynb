# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.990025, score: 22
# Scores: (min: 22, avg: 22, max: 22)
#
# Run: 2, exploration: 0.8911090557802088, score: 22
# Scores: (min: 22, avg: 22, max: 22)
#
# Run: 3, exploration: 0.6696478204705644, score: 58
# Scores: (min: 22, avg: 34, max: 58)
#
# Run: 4, exploration: 0.6369088258938781, score: 11
# Scores: (min: 11, avg: 28.25, max: 58)
#
# Run: 5, exploration: 0.5790496471185967, score: 20
# Scores: (min: 11, avg: 26.6, max: 58)
#
# Run: 6, exploration: 0.5452463540625918, score: 13
# Scores: (min: 11, avg: 24.333333333333332, max: 58)
#
# Run: 7, exploration: 0.5134164023722473, score: 13
# Scores: (min: 11, avg: 22.714285714285715, max: 58)
#
# Run: 8, exploration: 0.47147873742168567, score: 18
# Scores: (min: 11, avg: 22.125, max: 58)
#
# Run: 9, exploration: 0.4439551321314536, score: 13
# Scores: (min: 11, avg: 21.11111111111111, max: 58)
#
# Run: 10, exploration: 0.40974000909221303, score: 17
# Scores: (min: 11, avg: 20.7, max: 58)
#
# Run: 11, exploration: 0.3819719776053028, score: 15
# Scores: (min: 11, avg: 20.181818181818183, max: 58)
#
# Run: 12, exploration: 0.35253382661792404, score: 17
# Scores: (min: 11, avg: 19.916666666666668, max: 58)
#
# Run: 13, exploration: 0.33195389135223546, score: 13
# Scores: (min: 11, avg: 19.384615384615383, max: 58)
#
# Run: 14, exploration: 0.3125753549412418, score: 13
# Scores: (min: 11, avg: 18.928571428571427, max: 58)
#
# Run: 15, exploration: 0.29580711868545667, score: 12
# Scores: (min: 11, avg: 18.466666666666665, max: 58)
#
# Run: 16, exploration: 0.2799384215094006, score: 12
# Scores: (min: 11, avg: 18.0625, max: 58)
#
# Run: 17, exploration: 0.2702863258025825, score: 8
# Scores: (min: 8, avg: 17.470588235294116, max: 58)
#
# Run: 18, exploration: 0.25578670228422234, score: 12
# Scores: (min: 8, avg: 17.166666666666668, max: 58)
#
# Run: 19, exploration: 0.24450384299593592, score: 10
# Scores: (min: 8, avg: 16.789473684210527, max: 58)
#
# Run: 20, exploration: 0.23607350863684065, score: 8
# Scores: (min: 8, avg: 16.35, max: 58)
#
# Run: 21, exploration: 0.22566020663225933, score: 10
# Scores: (min: 8, avg: 16.047619047619047, max: 58)
#
# Run: 22, exploration: 0.21355457002808648, score: 12
# Scores: (min: 8, avg: 15.863636363636363, max: 58)
#
# Run: 23, exploration: 0.2041345879004775, score: 10
# Scores: (min: 8, avg: 15.608695652173912, max: 58)
#
# Run: 24, exploration: 0.19318370215794672, score: 12
# Scores: (min: 8, avg: 15.458333333333334, max: 58)
#
# Run: 25, exploration: 0.18099664897669618, score: 14
# Scores: (min: 8, avg: 15.4, max: 58)
#
# Run: 26, exploration: 0.1712870076899825, score: 12
# Scores: (min: 8, avg: 15.26923076923077, max: 58)
#
# Run: 27, exploration: 0.15888051309497406, score: 16
# Scores: (min: 8, avg: 15.296296296296296, max: 58)
#
# Run: 28, exploration: 0.14590259167570602, score: 18
# Scores: (min: 8, avg: 15.392857142857142, max: 58)
#
# Run: 29, exploration: 0.1313250884614265, score: 22
# Scores: (min: 8, avg: 15.620689655172415, max: 58)
#
# Run: 30, exploration: 0.1042820154910064, score: 47
# Scores: (min: 8, avg: 16.666666666666668, max: 58)
#
# Run: 31, exploration: 0.0712465030521374, score: 77
# Scores: (min: 8, avg: 18.612903225806452, max: 77)
#
# Run: 32, exploration: 0.06412808167716157, score: 22
# Scores: (min: 8, avg: 18.71875, max: 77)
#
# Run: 33, exploration: 0.058010934765067, score: 21
# Scores: (min: 8, avg: 18.78787878787879, max: 77)
#
# Run: 34, exploration: 0.05195383849590569, score: 23
# Scores: (min: 8, avg: 18.91176470588235, max: 77)
#
# Run: 35, exploration: 0.04272851397543923, score: 40
# Scores: (min: 8, avg: 19.514285714285716, max: 77)
#
# Run: 36, exploration: 0.024008889611965685, score: 116
# Scores: (min: 8, avg: 22.194444444444443, max: 116)
#
# Run: 37, exploration: 0.018874695352408037, score: 49
# Scores: (min: 8, avg: 22.91891891891892, max: 116)
#
# Run: 38, exploration: 0.011433732442257729, score: 101
# Scores: (min: 8, avg: 24.973684210526315, max: 116)
#
# Run: 39, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 26.307692307692307, max: 116)
#
# Run: 40, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 27.275, max: 116)
#
# Run: 41, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 27.853658536585368, max: 116)
#
# Run: 42, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 28.69047619047619, max: 116)
#
# Run: 43, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 30.348837209302324, max: 116)
#
# Run: 44, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 31.318181818181817, max: 116)
#
# Run: 45, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 32.48888888888889, max: 116)
#
# Run: 46, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 33.34782608695652, max: 116)
#
# Run: 47, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 35.297872340425535, max: 125)
#
# Run: 48, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 36.5, max: 125)
#
# Run: 49, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 36.734693877551024, max: 125)
#
# Run: 50, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 37.78, max: 125)
#
# Run: 51, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 37.80392156862745, max: 125)
#
# Run: 52, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 38.90384615384615, max: 125)
#
# Run: 53, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 39.15094339622642, max: 125)
#
# Run: 54, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 39.5, max: 125)
#
# Run: 55, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 40.41818181818182, max: 125)
#
# Run: 56, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 41.357142857142854, max: 125)
#
# Run: 57, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 42.03508771929825, max: 125)
#
# Run: 58, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 42.724137931034484, max: 125)
#
# Run: 59, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 43.45762711864407, max: 125)
#
# Run: 60, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 44.35, max: 125)
#
# Run: 61, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 45.049180327868854, max: 125)
#
# Run: 62, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 46.016129032258064, max: 125)
#
# Run: 63, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 46.492063492063494, max: 125)
#
# Run: 64, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 47.234375, max: 125)
#
# Run: 65, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 48.55384615384615, max: 133)
#
# Run: 66, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 49.03030303030303, max: 133)
#
# Run: 67, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 49.940298507462686, max: 133)
#
# Run: 68, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 51.0735294117647, max: 133)
#
# Run: 69, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 52.52173913043478, max: 151)
#
# Run: 70, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 53.84285714285714, max: 151)
#
# Run: 71, exploration: 0.01, score: 311
# Scores: (min: 8, avg: 57.46478873239437, max: 311)
#
# Run: 72, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 59.40277777777778, max: 311)
#
# Run: 73, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 61.397260273972606, max: 311)
#
# Run: 74, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 63.472972972972975, max: 311)
#
# Run: 75, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 64.85333333333334, max: 311)
#
# Run: 76, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 66.38157894736842, max: 311)
#
# Run: 77, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 68.11688311688312, max: 311)
#
# Run: 78, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 69.44871794871794, max: 311)
#
# Run: 79, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 71.21518987341773, max: 311)
#
# Run: 80, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 72.725, max: 311)
#
# Run: 81, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 74.66666666666667, max: 311)
#
# Run: 82, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 76.09756097560975, max: 311)
#
# Run: 83, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 78.3855421686747, max: 311)
#
# Run: 84, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 79.26190476190476, max: 311)
#
# Run: 85, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 80.18823529411765, max: 311)
#
# Run: 86, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 81.09302325581395, max: 311)
#
# Run: 87, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 81.79310344827586, max: 311)
#
# Run: 88, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 82.7159090909091, max: 311)
# Run: 89, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 83.65168539325843, max: 311)
#
# Run: 90, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 84.57777777777778, max: 311)
#
# Run: 91, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 84.89010989010988, max: 311)
#
# Run: 92, exploration: 0.01, score: 244
# Scores: (min: 8, avg: 86.6195652173913, max: 311)
#
# Run: 93, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 87.26881720430107, max: 311)
#
# Run: 94, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 87.87234042553192, max: 311)
#
# Run: 95, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 88.6842105263158, max: 311)
#
# Run: 96, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 89.33333333333333, max: 311)
#
# Run: 97, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 89.77319587628865, max: 311)
#
# Run: 98, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 90.42857142857143, max: 311)
#
# Run: 99, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 91.08080808080808, max: 311)
#
# Run: 100, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 91.55, max: 311)
#
# Run: 101, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 92.76, max: 311)
#
# Run: 102, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 94.11, max: 311)
#
# Run: 103, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 95.65, max: 311)
#
# Run: 104, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 96.89, max: 311)
#
# Run: 105, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 98.14, max: 311)
#
# Run: 106, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 99.98, max: 311)
#
# Run: 107, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 101.32, max: 311)
#
# Run: 108, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 102.48, max: 311)
#
# Run: 109, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 103.61, max: 311)
#
# Run: 110, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 104.32, max: 311)
#
# Run: 111, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 105.18, max: 311)
#
# Run: 112, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 105.81, max: 311)
#
# Run: 113, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 106.93, max: 311)
#
# Run: 114, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 108.65, max: 311)
#
# Run: 115, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 110.45, max: 311)
#
# Run: 116, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 111.95, max: 311)
#
# Run: 117, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 113.36, max: 311)
#
# Run: 118, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 114.57, max: 311)
#
# Run: 119, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 116, max: 311)
#
# Run: 120, exploration: 0.01, score: 83
# Scores: (min: 10, avg: 116.75, max: 311)
#
# Run: 121, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 117.9, max: 311)
#
# Run: 122, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 118.84, max: 311)
#
# Run: 123, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 120.42, max: 311)
#
# Run: 124, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 121.42, max: 311)
#
# Run: 125, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 122.45, max: 311)
#
# Run: 126, exploration: 0.01, score: 114
# Scores: (min: 16, avg: 123.47, max: 311)
#
# Run: 127, exploration: 0.01, score: 92
# Scores: (min: 18, avg: 124.23, max: 311)
#
# Run: 128, exploration: 0.01, score: 89
# Scores: (min: 21, avg: 124.94, max: 311)
#
# Run: 129, exploration: 0.01, score: 132
# Scores: (min: 21, avg: 126.04, max: 311)
#
# Run: 130, exploration: 0.01, score: 98
# Scores: (min: 21, avg: 126.55, max: 311)
#
# Run: 131, exploration: 0.01, score: 139
# Scores: (min: 21, avg: 127.17, max: 311)
#
# Run: 132, exploration: 0.01, score: 137
# Scores: (min: 21, avg: 128.32, max: 311)
#
# Run: 133, exploration: 0.01, score: 138
# Scores: (min: 23, avg: 129.49, max: 311)
#
# Run: 134, exploration: 0.01, score: 127
# Scores: (min: 39, avg: 130.53, max: 311)
#
# Run: 135, exploration: 0.01, score: 135
# Scores: (min: 39, avg: 131.48, max: 311)
#
# Run: 136, exploration: 0.01, score: 106
# Scores: (min: 39, avg: 131.38, max: 311)
#
# Run: 137, exploration: 0.01, score: 162
# Scores: (min: 39, avg: 132.51, max: 311)
#
# Run: 138, exploration: 0.01, score: 124
# Scores: (min: 39, avg: 132.74, max: 311)
#
# Run: 139, exploration: 0.01, score: 89
# Scores: (min: 39, avg: 132.86, max: 311)
#
# Run: 140, exploration: 0.01, score: 104
# Scores: (min: 39, avg: 133.25, max: 311)
#
# Run: 141, exploration: 0.01, score: 42
# Scores: (min: 39, avg: 133.16, max: 311)
#
# Run: 142, exploration: 0.01, score: 126
# Scores: (min: 39, avg: 133.79, max: 311)
#
# Run: 143, exploration: 0.01, score: 128
# Scores: (min: 39, avg: 134.07, max: 311)
#
# Run: 144, exploration: 0.01, score: 117
# Scores: (min: 39, avg: 134.51, max: 311)
#
# Run: 145, exploration: 0.01, score: 119
# Scores: (min: 39, avg: 134.86, max: 311)
#
# Run: 146, exploration: 0.01, score: 127
# Scores: (min: 39, avg: 135.41, max: 311)
#
# Run: 147, exploration: 0.01, score: 160
# Scores: (min: 39, avg: 135.76, max: 311)
#
# Run: 148, exploration: 0.01, score: 35
# Scores: (min: 35, avg: 135.18, max: 311)
#
# Run: 149, exploration: 0.01, score: 131
# Scores: (min: 35, avg: 136.01, max: 311)
#
# Run: 150, exploration: 0.01, score: 124
# Scores: (min: 35, avg: 136.36, max: 311)
#
# Run: 151, exploration: 0.01, score: 135
# Scores: (min: 35, avg: 137.32, max: 311)
#
# Run: 152, exploration: 0.01, score: 163
# Scores: (min: 35, avg: 138, max: 311)
#
# Run: 153, exploration: 0.01, score: 157
# Scores: (min: 35, avg: 139.05, max: 311)
#
# Run: 154, exploration: 0.01, score: 116
# Scores: (min: 35, avg: 139.63, max: 311)
#
# Run: 155, exploration: 0.01, score: 124
# Scores: (min: 35, avg: 139.97, max: 311)
#
# Run: 156, exploration: 0.01, score: 189
# Scores: (min: 35, avg: 140.93, max: 311)
#
# Run: 157, exploration: 0.01, score: 144
# Scores: (min: 35, avg: 141.57, max: 311)
#
# Run: 158, exploration: 0.01, score: 149
# Scores: (min: 35, avg: 142.24, max: 311)
#
# Run: 159, exploration: 0.01, score: 113
# Scores: (min: 35, avg: 142.51, max: 311)
#
# Run: 160, exploration: 0.01, score: 126
# Scores: (min: 35, avg: 142.8, max: 311)
#
# Run: 161, exploration: 0.01, score: 210
# Scores: (min: 35, avg: 144.03, max: 311)
#
# Run: 162, exploration: 0.01, score: 105
# Scores: (min: 35, avg: 144.03, max: 311)
#
# Run: 163, exploration: 0.01, score: 156
# Scores: (min: 35, avg: 144.83, max: 311)
#
# Run: 164, exploration: 0.01, score: 150
# Scores: (min: 35, avg: 145.39, max: 311)
#
# Run: 165, exploration: 0.01, score: 165
# Scores: (min: 35, avg: 145.71, max: 311)
#
# Run: 166, exploration: 0.01, score: 204
# Scores: (min: 35, avg: 146.95, max: 311)
#
# Run: 167, exploration: 0.01, score: 116
# Scores: (min: 35, avg: 147.01, max: 311)
#
# Run: 168, exploration: 0.01, score: 145
# Scores: (min: 35, avg: 147.19, max: 311)
#
# Run: 169, exploration: 0.01, score: 141
# Scores: (min: 35, avg: 147.09, max: 311)
#
# Run: 170, exploration: 0.01, score: 127
# Scores: (min: 35, avg: 146.91, max: 311)
#
# Run: 171, exploration: 0.01, score: 89
# Scores: (min: 35, avg: 144.69, max: 266)
#
# Run: 172, exploration: 0.01, score: 107
# Scores: (min: 35, avg: 143.79, max: 266)
#
# Run: 173, exploration: 0.01, score: 151
# Scores: (min: 35, avg: 143.25, max: 266)
#
# Run: 174, exploration: 0.01, score: 196
# Scores: (min: 35, avg: 143.06, max: 266)
#
# Run: 175, exploration: 0.01, score: 157
# Scores: (min: 35, avg: 142.96, max: 266)
#
# Run: 176, exploration: 0.01, score: 128
# Scores: (min: 35, avg: 142.43, max: 266)
#
# Run: 177, exploration: 0.01, score: 137
# Scores: (min: 35, avg: 141.8, max: 266)
#
# Run: 178, exploration: 0.01, score: 322
# Scores: (min: 35, avg: 143.3, max: 322)
#
# Run: 179, exploration: 0.01, score: 178
# Scores: (min: 35, avg: 142.99, max: 322)
#
# Run: 180, exploration: 0.01, score: 130
# Scores: (min: 35, avg: 142.37, max: 322)
#
# Run: 181, exploration: 0.01, score: 174
# Scores: (min: 35, avg: 141.81, max: 322)
#
# Run: 182, exploration: 0.01, score: 141
# Scores: (min: 35, avg: 141.3, max: 322)
#
# Run: 183, exploration: 0.01, score: 125
# Scores: (min: 35, avg: 139.89, max: 322)
#
# Run: 184, exploration: 0.01, score: 149
# Scores: (min: 35, avg: 139.86, max: 322)
#
# Run: 185, exploration: 0.01, score: 155
# Scores: (min: 35, avg: 139.83, max: 322)
#
# Run: 186, exploration: 0.01, score: 168
# Scores: (min: 35, avg: 139.93, max: 322)
#
# Run: 187, exploration: 0.01, score: 153
# Scores: (min: 35, avg: 140.04, max: 322)
#
# Run: 188, exploration: 0.01, score: 54
# Scores: (min: 35, avg: 138.95, max: 322)
# Run: 189, exploration: 0.01, score: 111
# Scores: (min: 35, avg: 138.4, max: 322)
#
# Run: 190, exploration: 0.01, score: 126
# Scores: (min: 35, avg: 137.99, max: 322)
#
# Run: 191, exploration: 0.01, score: 149
# Scores: (min: 35, avg: 138.35, max: 322)
#
# Run: 192, exploration: 0.01, score: 119
# Scores: (min: 35, avg: 137.1, max: 322)
#
# Run: 193, exploration: 0.01, score: 194
# Scores: (min: 35, avg: 137.57, max: 322)
#
# Run: 194, exploration: 0.01, score: 120
# Scores: (min: 35, avg: 137.33, max: 322)
#
# Run: 195, exploration: 0.01, score: 212
# Scores: (min: 35, avg: 137.8, max: 322)
#
# Run: 196, exploration: 0.01, score: 158
# Scores: (min: 35, avg: 137.87, max: 322)
#
# Run: 197, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 136.67, max: 322)
#
# Run: 198, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 136.77, max: 322)
#
# Run: 199, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 136.13, max: 322)
#
# Run: 200, exploration: 0.01, score: 167
# Scores: (min: 12, avg: 136.42, max: 322)
#
# Run: 201, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 136.53, max: 322)
#
# Run: 202, exploration: 0.01, score: 81
# Scores: (min: 12, avg: 135.77, max: 322)
#
# Run: 203, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 134.11, max: 322)
#
# Run: 204, exploration: 0.01, score: 74
# Scores: (min: 12, avg: 133.5, max: 322)
#
# Run: 205, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 133.4, max: 322)
#
# Run: 206, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 132.34, max: 322)
#
# Run: 207, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 132.18, max: 322)
#
# Run: 208, exploration: 0.01, score: 61
# Scores: (min: 12, avg: 131.45, max: 322)
#
# Run: 209, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 130.31, max: 322)
#
# Run: 210, exploration: 0.01, score: 270
# Scores: (min: 12, avg: 132.13, max: 322)
#
# Run: 211, exploration: 0.01, score: 167
# Scores: (min: 12, avg: 132.79, max: 322)
#
# Run: 212, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 132.92, max: 322)
#
# Run: 213, exploration: 0.01, score: 42
# Scores: (min: 12, avg: 132.09, max: 322)
#
# Run: 214, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 131.66, max: 322)
#
# Run: 215, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 129.88, max: 322)
#
# Run: 216, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 128.4, max: 322)
#
# Run: 217, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 127.71, max: 322)
#
# Run: 218, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 127.74, max: 322)
#
# Run: 219, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 127.36, max: 322)
#
# Run: 220, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 128.13, max: 322)
#
# Run: 221, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 128.15, max: 322)
#
# Run: 222, exploration: 0.01, score: 198
# Scores: (min: 12, avg: 129.07, max: 322)
#
# Run: 223, exploration: 0.01, score: 276
# Scores: (min: 12, avg: 130.15, max: 322)
#
# Run: 224, exploration: 0.01, score: 359
# Scores: (min: 12, avg: 132.62, max: 359)
#
# Run: 225, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 133.15, max: 359)
#
# Run: 226, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 133.22, max: 359)
#
# Run: 227, exploration: 0.01, score: 218
# Scores: (min: 12, avg: 134.48, max: 359)
#
# Run: 228, exploration: 0.01, score: 400
# Scores: (min: 12, avg: 137.59, max: 400)
#
# Run: 229, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 137.32, max: 400)
#
# Run: 230, exploration: 0.01, score: 157
# Scores: (min: 12, avg: 137.91, max: 400)
#
# Run: 231, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 137.62, max: 400)
#
# Run: 232, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 137.61, max: 400)
#
# Run: 233, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 138.08, max: 400)
#
# Run: 234, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 138.15, max: 400)
#
# Run: 235, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 137.74, max: 400)
#
# Run: 236, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 137.75, max: 400)
#
# Run: 237, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 137.29, max: 400)
#
# Run: 238, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 137.24, max: 400)
#
# Run: 239, exploration: 0.01, score: 152
# Scores: (min: 12, avg: 137.87, max: 400)
#
# Run: 240, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 138.41, max: 400)
#
# Run: 241, exploration: 0.01, score: 225
# Scores: (min: 12, avg: 140.24, max: 400)
#
# Run: 242, exploration: 0.01, score: 178
# Scores: (min: 12, avg: 140.76, max: 400)
#
# Run: 243, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 141.02, max: 400)
#
# Run: 244, exploration: 0.01, score: 211
# Scores: (min: 12, avg: 141.96, max: 400)
#
# Run: 245, exploration: 0.01, score: 319
# Scores: (min: 12, avg: 143.96, max: 400)
#
# Run: 246, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 143.85, max: 400)
#
# Run: 247, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 144.01, max: 400)
#
# Run: 248, exploration: 0.01, score: 385
# Scores: (min: 12, avg: 147.51, max: 400)
#
# Run: 249, exploration: 0.01, score: 214
# Scores: (min: 12, avg: 148.34, max: 400)
#
# Run: 250, exploration: 0.01, score: 338
# Scores: (min: 12, avg: 150.48, max: 400)
#
# Run: 251, exploration: 0.01, score: 333
# Scores: (min: 12, avg: 152.46, max: 400)
#
# Run: 252, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 152.59, max: 400)
#
# Run: 253, exploration: 0.01, score: 174
# Scores: (min: 12, avg: 152.76, max: 400)
#
# Run: 254, exploration: 0.01, score: 274
# Scores: (min: 12, avg: 154.34, max: 400)
#
# Run: 255, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 155.1, max: 400)
#
# Run: 256, exploration: 0.01, score: 177
# Scores: (min: 12, avg: 154.98, max: 400)
#
# Run: 257, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 154.82, max: 400)
#
# Run: 258, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 154.84, max: 400)
#
# Run: 259, exploration: 0.01, score: 229
# Scores: (min: 12, avg: 156, max: 400)
#
# Run: 260, exploration: 0.01, score: 205
# Scores: (min: 12, avg: 156.79, max: 400)
#
# Run: 261, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 156.23, max: 400)
#
# Run: 262, exploration: 0.01, score: 209
# Scores: (min: 12, avg: 157.27, max: 400)
#
# Run: 263, exploration: 0.01, score: 392
# Scores: (min: 12, avg: 159.63, max: 400)
#
# Run: 264, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 159.66, max: 400)
#
# Run: 265, exploration: 0.01, score: 232
# Scores: (min: 12, avg: 160.33, max: 400)
#
# Run: 266, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 159.97, max: 400)
#
# Run: 267, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 159.95, max: 400)
#
# Run: 268, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 163.5, max: 500)
#
# Run: 269, exploration: 0.01, score: 419
# Scores: (min: 12, avg: 166.28, max: 500)
#
# Run: 270, exploration: 0.01, score: 147
# Scores: (min: 12, avg: 166.48, max: 500)
#
# Run: 271, exploration: 0.01, score: 207
# Scores: (min: 12, avg: 167.66, max: 500)
#
# Run: 272, exploration: 0.01, score: 184
# Scores: (min: 12, avg: 168.43, max: 500)
#
# Run: 273, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 168.2, max: 500)
#
# Run: 274, exploration: 0.01, score: 251
# Scores: (min: 12, avg: 168.75, max: 500)
#
# Run: 275, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 168.56, max: 500)
#
# Run: 276, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 168.38, max: 500)
#
# Run: 277, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 168, max: 500)
#
# Run: 278, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 165.85, max: 500)
#
# Run: 279, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 165.39, max: 500)
#
# Run: 280, exploration: 0.01, score: 242
# Scores: (min: 12, avg: 166.51, max: 500)
#
# Run: 281, exploration: 0.01, score: 229
# Scores: (min: 12, avg: 167.06, max: 500)
#
# Run: 282, exploration: 0.01, score: 474
# Scores: (min: 12, avg: 170.39, max: 500)
#
# Run: 283, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 170.87, max: 500)
#
# Run: 284, exploration: 0.01, score: 367
# Scores: (min: 12, avg: 173.05, max: 500)
#
# Run: 285, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 172.84, max: 500)
#
# Run: 286, exploration: 0.01, score: 342
# Scores: (min: 12, avg: 174.58, max: 500)
#
# Run: 287, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 174.65, max: 500)
#
# Run: 288, exploration: 0.01, score: 382
# Scores: (min: 12, avg: 177.93, max: 500)
#
# Run: 289, exploration: 0.01, score: 311
# Scores: (min: 12, avg: 179.93, max: 500)
# Run: 290, exploration: 0.01, score: 391
# Scores: (min: 12, avg: 182.58, max: 500)
#
# Run: 291, exploration: 0.01, score: 211
# Scores: (min: 12, avg: 183.2, max: 500)
#
# Run: 292, exploration: 0.01, score: 202
# Scores: (min: 12, avg: 184.03, max: 500)
#
# Run: 293, exploration: 0.01, score: 197
# Scores: (min: 12, avg: 184.06, max: 500)
#
# Run: 294, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 184.01, max: 500)
#
# Run: 295, exploration: 0.01, score: 90
# Scores: (min: 12, avg: 182.79, max: 500)
#
# Run: 296, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 182.87, max: 500)
#
# Run: 297, exploration: 0.01, score: 159
# Scores: (min: 12, avg: 184.34, max: 500)
#
# Run: 298, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 183.84, max: 500)
#
# Run: 299, exploration: 0.01, score: 341
# Scores: (min: 12, avg: 186.34, max: 500)
#
# Run: 300, exploration: 0.01, score: 433
# Scores: (min: 12, avg: 189, max: 500)
#
# Run: 301, exploration: 0.01, score: 302
# Scores: (min: 12, avg: 190.48, max: 500)
#
# Run: 302, exploration: 0.01, score: 485
# Scores: (min: 12, avg: 194.52, max: 500)
#
# Run: 303, exploration: 0.01, score: 295
# Scores: (min: 12, avg: 197.01, max: 500)
#
# Solved in 203 runs, 303 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
# Adjusted learning rate to 0.01 from 0.001
LEARNING_RATE = 0.01  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9046104802746175, score: 40
# Scores: (min: 40, avg: 40, max: 40)
#
# Run: 2, exploration: 0.7552531090661897, score: 37
# Scores: (min: 37, avg: 38.5, max: 40)
#
# Run: 3, exploration: 0.6730128848950395, score: 24
# Scores: (min: 24, avg: 33.666666666666664, max: 40)
#
# Run: 4, exploration: 0.6180388156137953, score: 18
# Scores: (min: 18, avg: 29.75, max: 40)
#
# Run: 5, exploration: 0.5819594443402982, score: 13
# Scores: (min: 13, avg: 26.4, max: 40)
#
# Run: 6, exploration: 0.5535075230322891, score: 11
# Scores: (min: 11, avg: 23.833333333333332, max: 40)
#
# Run: 7, exploration: 0.531750826943791, score: 9
# Scores: (min: 9, avg: 21.714285714285715, max: 40)
#
# Run: 8, exploration: 0.5032248303978422, score: 12
# Scores: (min: 9, avg: 20.5, max: 40)
#
# Run: 9, exploration: 0.46444185833082485, score: 17
# Scores: (min: 9, avg: 20.11111111111111, max: 40)
#
# Run: 10, exploration: 0.4417353564707963, score: 11
# Scores: (min: 9, avg: 19.2, max: 40)
#
# Run: 11, exploration: 0.41386834584198684, score: 14
# Scores: (min: 9, avg: 18.727272727272727, max: 40)
#
# Run: 12, exploration: 0.3743896431025813, score: 21
# Scores: (min: 9, avg: 18.916666666666668, max: 40)
#
# Run: 13, exploration: 0.3420891339682016, score: 19
# Scores: (min: 9, avg: 18.923076923076923, max: 40)
#
# Run: 14, exploration: 0.3237376186352221, score: 12
# Scores: (min: 9, avg: 18.428571428571427, max: 40)
#
# Run: 15, exploration: 0.30945741577570285, score: 10
# Scores: (min: 9, avg: 17.866666666666667, max: 40)
#
# Run: 16, exploration: 0.29285644267656924, score: 12
# Scores: (min: 9, avg: 17.5, max: 40)
#
# Run: 17, exploration: 0.27853872940185365, score: 11
# Scores: (min: 9, avg: 17.11764705882353, max: 40)
#
# Run: 18, exploration: 0.26759021970270175, score: 9
# Scores: (min: 9, avg: 16.666666666666668, max: 40)
#
# Run: 19, exploration: 0.2570720625972084, score: 9
# Scores: (min: 9, avg: 16.263157894736842, max: 40)
#
# Run: 20, exploration: 0.24696734223472733, score: 9
# Scores: (min: 9, avg: 15.9, max: 40)
#
# Run: 21, exploration: 0.23371867538818816, score: 12
# Scores: (min: 9, avg: 15.714285714285714, max: 40)
#
# Run: 22, exploration: 0.2211807388415433, score: 12
# Scores: (min: 9, avg: 15.545454545454545, max: 40)
#
# Run: 23, exploration: 0.20931540516921554, score: 12
# Scores: (min: 9, avg: 15.391304347826088, max: 40)
#
# Run: 24, exploration: 0.19808659230739353, score: 12
# Scores: (min: 9, avg: 15.25, max: 40)
#
# Run: 25, exploration: 0.18934890919900021, score: 10
# Scores: (min: 9, avg: 15.04, max: 40)
#
# Run: 26, exploration: 0.17740377510930716, score: 14
# Scores: (min: 9, avg: 15, max: 40)
#
# Run: 27, exploration: 0.16957841978827493, score: 10
# Scores: (min: 9, avg: 14.814814814814815, max: 40)
#
# Run: 28, exploration: 0.16209824418995536, score: 10
# Scores: (min: 9, avg: 14.642857142857142, max: 40)
#
# Run: 29, exploration: 0.15650920157696743, score: 8
# Scores: (min: 8, avg: 14.413793103448276, max: 40)
#
# Run: 30, exploration: 0.14885748713096328, score: 11
# Scores: (min: 8, avg: 14.3, max: 40)
#
# Run: 31, exploration: 0.14300635237083656, score: 9
# Scores: (min: 8, avg: 14.129032258064516, max: 40)
#
# Run: 32, exploration: 0.13807558583895513, score: 8
# Scores: (min: 8, avg: 13.9375, max: 40)
#
# Run: 33, exploration: 0.13264825480308728, score: 9
# Scores: (min: 8, avg: 13.787878787878787, max: 40)
#
# Run: 34, exploration: 0.12807462877562611, score: 8
# Scores: (min: 8, avg: 13.617647058823529, max: 40)
#
# Run: 35, exploration: 0.12242520289863423, score: 10
# Scores: (min: 8, avg: 13.514285714285714, max: 40)
#
# Run: 36, exploration: 0.11702497557911415, score: 10
# Scores: (min: 8, avg: 13.416666666666666, max: 40)
#
# Run: 37, exploration: 0.11074712159185099, score: 12
# Scores: (min: 8, avg: 13.378378378378379, max: 40)
#
# Run: 38, exploration: 0.10586201936274783, score: 10
# Scores: (min: 8, avg: 13.289473684210526, max: 40)
#
# Run: 39, exploration: 0.10119240105273684, score: 10
# Scores: (min: 8, avg: 13.205128205128204, max: 40)
#
# Run: 40, exploration: 0.09721483575406, score: 9
# Scores: (min: 8, avg: 13.1, max: 40)
#
# Run: 41, exploration: 0.09246201511725258, score: 11
# Scores: (min: 8, avg: 13.048780487804878, max: 40)
#
# Run: 42, exploration: 0.08706434220766679, score: 13
# Scores: (min: 8, avg: 13.047619047619047, max: 40)
#
# Run: 43, exploration: 0.0832238973628649, score: 10
# Scores: (min: 8, avg: 12.976744186046512, max: 40)
#
# Run: 44, exploration: 0.08035439121179945, score: 8
# Scores: (min: 8, avg: 12.863636363636363, max: 40)
#
# Run: 45, exploration: 0.07719590465791494, score: 9
# Scores: (min: 8, avg: 12.777777777777779, max: 40)
#
# Run: 46, exploration: 0.07416156859737154, score: 9
# Scores: (min: 8, avg: 12.695652173913043, max: 40)
#
# Run: 47, exploration: 0.0708902705368767, score: 10
# Scores: (min: 8, avg: 12.638297872340425, max: 40)
#
# Run: 48, exploration: 0.06810378976195819, score: 9
# Scores: (min: 8, avg: 12.5625, max: 40)
#
# Run: 49, exploration: 0.06509970288011008, score: 10
# Scores: (min: 8, avg: 12.510204081632653, max: 40)
#
# Run: 50, exploration: 0.05978212923978115, score: 18
# Scores: (min: 8, avg: 12.62, max: 40)
#
# Run: 51, exploration: 0.04470026135116646, score: 59
# Scores: (min: 8, avg: 13.529411764705882, max: 59)
#
# Run: 52, exploration: 0.030539660091838977, score: 77
# Scores: (min: 8, avg: 14.75, max: 77)
#
# Run: 53, exploration: 0.0280450728002803, score: 18
# Scores: (min: 8, avg: 14.81132075471698, max: 77)
#
# Run: 54, exploration: 0.02562548094765099, score: 19
# Scores: (min: 8, avg: 14.88888888888889, max: 77)
#
# Run: 55, exploration: 0.02437265452736848, score: 11
# Scores: (min: 8, avg: 14.818181818181818, max: 77)
#
# Run: 56, exploration: 0.021937519923982282, score: 22
# Scores: (min: 8, avg: 14.946428571428571, max: 77)
#
# Run: 57, exploration: 0.020969846670345987, score: 10
# Scores: (min: 8, avg: 14.859649122807017, max: 77)
#
# Run: 58, exploration: 0.019944633602480003, score: 11
# Scores: (min: 8, avg: 14.793103448275861, max: 77)
#
# Run: 59, exploration: 0.019160670758563442, score: 9
# Scores: (min: 8, avg: 14.694915254237289, max: 77)
#
# Run: 60, exploration: 0.018223908064988973, score: 11
# Scores: (min: 8, avg: 14.633333333333333, max: 77)
#
# Run: 61, exploration: 0.0175075817047932, score: 9
# Scores: (min: 8, avg: 14.540983606557377, max: 77)
#
# Run: 62, exploration: 0.016651638319386028, score: 11
# Scores: (min: 8, avg: 14.483870967741936, max: 77)
#
# Run: 63, exploration: 0.01583754189442009, score: 11
# Scores: (min: 8, avg: 14.428571428571429, max: 77)
#
# Run: 64, exploration: 0.015138941243677408, score: 10
# Scores: (min: 8, avg: 14.359375, max: 77)
#
# Run: 65, exploration: 0.014543875539898159, score: 9
# Scores: (min: 8, avg: 14.276923076923078, max: 77)
#
# Run: 66, exploration: 0.013558238831322046, score: 15
# Scores: (min: 8, avg: 14.287878787878787, max: 77)
#
# Run: 67, exploration: 0.012766746905164949, score: 13
# Scores: (min: 8, avg: 14.26865671641791, max: 77)
#
# Run: 68, exploration: 0.012203600316175803, score: 10
# Scores: (min: 8, avg: 14.205882352941176, max: 77)
#
# Run: 69, exploration: 0.01137656378004644, score: 15
# Scores: (min: 8, avg: 14.217391304347826, max: 77)
#
# Run: 70, exploration: 0.010766263235786683, score: 12
# Scores: (min: 8, avg: 14.185714285714285, max: 77)
#
# Run: 71, exploration: 0.010239902030817916, score: 11
# Scores: (min: 8, avg: 14.140845070422536, max: 77)
#
# Run: 72, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.083333333333334, max: 77)
#
# Run: 73, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.013698630136986, max: 77)
#
# Run: 74, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.972972972972974, max: 77)
#
# Run: 75, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.893333333333333, max: 77)
#
# Run: 76, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.855263157894736, max: 77)
#
# Run: 77, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.87012987012987, max: 77)
#
# Run: 78, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.884615384615385, max: 77)
#
# Run: 79, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.822784810126583, max: 77)
#
# Run: 80, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.75, max: 77)
#
# Run: 81, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.753086419753087, max: 77)
#
# Run: 82, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.902439024390244, max: 77)
#
# Run: 83, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.891566265060241, max: 77)
# Run: 84, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 14.214285714285714, max: 77)
#
# Run: 85, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 14.447058823529412, max: 77)
#
# Run: 86, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.418604651162791, max: 77)
#
# Run: 87, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.574712643678161, max: 77)
#
# Run: 88, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.579545454545455, max: 77)
#
# Run: 89, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 14.853932584269662, max: 77)
#
# Run: 90, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.922222222222222, max: 77)
#
# Run: 91, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.967032967032967, max: 77)
#
# Run: 92, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 15.08695652173913, max: 77)
#
# Run: 93, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 15.505376344086022, max: 77)
#
# Run: 94, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.46808510638298, max: 77)
#
# Run: 95, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 15.789473684210526, max: 77)
#
# Run: 96, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.739583333333334, max: 77)
#
# Run: 97, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 16.030927835051546, max: 77)
#
# Run: 98, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.071428571428573, max: 77)
#
# Run: 99, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.161616161616163, max: 77)
#
# Run: 100, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.34, max: 77)
#
# Run: 101, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.18, max: 77)
#
# Run: 102, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 16.18, max: 77)
#
# Run: 103, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 16.56, max: 77)
#
# Run: 104, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.58, max: 77)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.55, max: 77)
#
# Run: 106, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 16.79, max: 77)
#
# Run: 107, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 17.4, max: 77)
#
# Run: 108, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.42, max: 77)
#
# Run: 109, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 17.46, max: 77)
#
# Run: 110, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.54, max: 77)
#
# Run: 111, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.55, max: 77)
#
# Run: 112, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.48, max: 77)
#
# Run: 113, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.56, max: 77)
#
# Run: 114, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.74, max: 77)
#
# Run: 115, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.94, max: 77)
#
# Run: 116, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 18.42, max: 77)
#
# Run: 117, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 19.18, max: 87)
#
# Run: 118, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 19.32, max: 87)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.33, max: 87)
#
# Run: 120, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 19.62, max: 87)
#
# Run: 121, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.67, max: 87)
#
# Run: 122, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.74, max: 87)
#
# Run: 123, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.72, max: 87)
#
# Run: 124, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.76, max: 87)
#
# Run: 125, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 19.87, max: 87)
#
# Run: 126, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 19.94, max: 87)
#
# Run: 127, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 20.19, max: 87)
#
# Run: 128, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.3, max: 87)
#
# Run: 129, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.39, max: 87)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.38, max: 87)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.38, max: 87)
#
# Run: 132, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.4, max: 87)
#
# Run: 133, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.4, max: 87)
#
# Run: 134, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.41, max: 87)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.41, max: 87)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.4, max: 87)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.38, max: 87)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.37, max: 87)
#
# Run: 139, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.36, max: 87)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.36, max: 87)
#
# Run: 141, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.35, max: 87)
#
# Run: 142, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.32, max: 87)
#
# Run: 143, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.3, max: 87)
#
# Run: 144, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.32, max: 87)
#
# Run: 145, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.33, max: 87)
#
# Run: 146, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.33, max: 87)
#
# Run: 147, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.31, max: 87)
#
# Run: 148, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.32, max: 87)
#
# Run: 149, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.32, max: 87)
#
# Run: 150, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.23, max: 87)
#
# Run: 151, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.74, max: 87)
#
# Run: 152, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.08, max: 87)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19, max: 87)
#
# Run: 154, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.9, max: 87)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.89, max: 87)
#
# Run: 156, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.77, max: 87)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.76, max: 87)
#
# Run: 158, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.73, max: 87)
#
# Run: 159, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.74, max: 87)
#
# Run: 160, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.75, max: 87)
#
# Run: 161, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 18.89, max: 87)
#
# Run: 162, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 19.49, max: 87)
#
# Run: 163, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 19.81, max: 87)
#
# Run: 164, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 20.02, max: 87)
#
# Run: 165, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 20.19, max: 87)
#
# Run: 166, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.4, max: 87)
#
# Run: 167, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.51, max: 87)
#
# Run: 168, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.6, max: 87)
#
# Run: 169, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.61, max: 87)
#
# Run: 170, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.67, max: 87)
#
# Run: 171, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.78, max: 87)
#
# Run: 172, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.88, max: 87)
#
# Run: 173, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.97, max: 87)
#
# Run: 174, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.05, max: 87)
#
# Run: 175, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 21.23, max: 87)
#
# Run: 176, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 21.45, max: 87)
#
# Run: 177, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.51, max: 87)
#
# Run: 178, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 21.62, max: 87)
#
# Run: 179, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.66, max: 87)
#
# Run: 180, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.71, max: 87)
#
# Run: 181, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 21.79, max: 87)
#
# Run: 182, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.66, max: 87)
#
# Run: 183, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 21.77, max: 87)
#
# Run: 184, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.48, max: 87)
#
# Run: 185, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.37, max: 87)
#
# Run: 186, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 21.39, max: 87)
# Run: 187, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.22, max: 87)
#
# Run: 188, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 21.27, max: 87)
#
# Run: 189, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 21.24, max: 87)
#
# Run: 190, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.16, max: 87)
#
# Run: 191, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.2, max: 87)
#
# Run: 192, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 21.14, max: 87)
#
# Run: 193, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.69, max: 87)
#
# Run: 194, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 21.06, max: 87)
#
# Run: 195, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.8, max: 87)
#
# Run: 196, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 20.98, max: 87)
#
# Run: 197, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 20.88, max: 87)
#
# Run: 198, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.84, max: 87)
#
# Run: 199, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.7, max: 87)
#
# Run: 200, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.54, max: 87)
#
# Run: 201, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 20.74, max: 87)
#
# Run: 202, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.47, max: 87)
#
# Run: 203, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 20.31, max: 87)
#
# Run: 204, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.21, max: 87)
#
# Run: 205, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 20.43, max: 87)
#
# Run: 206, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 20.35, max: 87)
#
# Run: 207, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 20.06, max: 87)
#
# Run: 208, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.03, max: 87)
#
# Run: 209, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 20.42, max: 87)
#
# Run: 210, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 20.89, max: 87)
#
# Run: 211, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 21.31, max: 87)
#
# Run: 212, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.3, max: 87)
#
# Run: 213, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.15, max: 87)
#
# Run: 214, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.17, max: 87)
#
# Run: 215, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.05, max: 87)
#
# Run: 216, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 20.68, max: 87)
#
# Run: 217, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 20.25, max: 71)
#
# Run: 218, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.22, max: 71)
#
# Run: 219, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.33, max: 71)
#
# Run: 220, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 20.47, max: 71)
#
# Run: 221, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.51, max: 71)
#
# Run: 222, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.47, max: 71)
#
# Run: 223, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 20.64, max: 71)
#
# Run: 224, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 20.89, max: 71)
#
# Run: 225, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 21.08, max: 71)
#
# Run: 226, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.98, max: 71)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.73, max: 71)
#
# Run: 228, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.62, max: 71)
#
# Run: 229, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.92, max: 71)
#
# Run: 230, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 21.12, max: 71)
#
# Run: 231, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.35, max: 71)
#
# Run: 232, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 21.54, max: 71)
#
# Run: 233, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.55, max: 71)
#
# Run: 234, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 21.77, max: 71)
#
# Run: 235, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 21.96, max: 71)
#
# Run: 236, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 22.01, max: 71)
#
# Run: 237, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 22.2, max: 71)
#
# Run: 238, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.22, max: 71)
#
# Run: 239, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 22.29, max: 71)
#
# Run: 240, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 22.48, max: 71)
#
# Run: 241, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.47, max: 71)
#
# Run: 242, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 22.93, max: 71)
#
# Run: 243, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.98, max: 71)
#
# Run: 244, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.98, max: 71)
#
# Run: 245, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.98, max: 71)
#
# Run: 246, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 23.15, max: 71)
#
# Run: 247, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.38, max: 71)
#
# Run: 248, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 23.56, max: 71)
#
# Run: 249, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 23.88, max: 71)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.9, max: 71)
#
# Run: 251, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 24.09, max: 71)
#
# Run: 252, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.1, max: 71)
#
# Run: 253, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.27, max: 71)
#
# Run: 254, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.29, max: 71)
#
# Run: 255, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.28, max: 71)
#
# Run: 256, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.33, max: 71)
#
# Run: 257, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 24.6, max: 71)
#
# Run: 258, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 24.64, max: 71)
#
# Run: 259, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 24.63, max: 71)
#
# Run: 260, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 24.61, max: 71)
#
# Run: 261, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 24.47, max: 71)
#
# Run: 262, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 23.94, max: 66)
#
# Run: 263, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 23.82, max: 66)
#
# Run: 264, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.83, max: 66)
#
# Run: 265, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.89, max: 66)
#
# Run: 266, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 23.83, max: 66)
#
# Run: 267, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 23.97, max: 66)
#
# Run: 268, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 23.98, max: 66)
#
# Run: 269, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 24.29, max: 66)
#
# Run: 270, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.26, max: 66)
#
# Run: 271, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 24.18, max: 66)
#
# Run: 272, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 24.24, max: 66)
#
# Run: 273, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 24.17, max: 66)
#
# Run: 274, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 24.14, max: 66)
#
# Run: 275, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 24.22, max: 66)
#
# Run: 276, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 23.99, max: 66)
#
# Run: 277, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 24.06, max: 66)
#
# Run: 278, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 23.97, max: 66)
#
# Run: 279, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.98, max: 66)
#
# Run: 280, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 24.01, max: 66)
#
# Run: 281, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 24.47, max: 68)
#
# Run: 282, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 24.52, max: 68)
#
# Run: 283, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 24.51, max: 68)
#
# Run: 284, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 24.56, max: 68)
#
# Run: 285, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 24.61, max: 68)
#
# Run: 286, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 24.6, max: 68)
#
# Run: 287, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 24.7, max: 68)
#
# Run: 288, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 24.6, max: 68)
#
# Run: 289, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 24.68, max: 68)
#
# Run: 290, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.7, max: 68)
#
# Run: 291, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 24.76, max: 68)
#
# Run: 292, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 24.67, max: 68)
# Run: 293, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.73, max: 68)
#
# Run: 294, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 24.37, max: 68)
#
# Run: 295, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 24.44, max: 68)
#
# Run: 296, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 24.26, max: 68)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 24.02, max: 68)
#
# Run: 298, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 24.12, max: 68)
#
# Run: 299, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 24.17, max: 68)
#
# Run: 300, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 24.36, max: 68)
#
# Run: 301, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.07, max: 68)
#
# Run: 302, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.12, max: 68)
#
# Run: 303, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 24.02, max: 68)
#
# Run: 304, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 24.14, max: 68)
#
# Run: 305, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 24.13, max: 68)
#
# Run: 306, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 24.08, max: 68)
#
# Run: 307, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 24.09, max: 68)
#
# Run: 308, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 24.19, max: 68)
#
# Run: 309, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 23.8, max: 68)
#
# Run: 310, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 23.35, max: 68)
#
# Run: 311, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 23.09, max: 68)
#
# Run: 312, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 23.35, max: 68)
#
# Run: 313, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 23.39, max: 68)
#
# Run: 314, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 23.45, max: 68)
#
# Run: 315, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 23.56, max: 68)
#
# Run: 316, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 23.72, max: 68)
#
# Run: 317, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 23.45, max: 68)
#
# Run: 318, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 23.68, max: 68)
#
# Run: 319, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 23.65, max: 68)
#
# Run: 320, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 23.25, max: 68)
#
# Run: 321, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 23.45, max: 68)
#
# Run: 322, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.38, max: 68)
#
# Run: 323, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 23.6, max: 68)
#
# Run: 324, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.55, max: 68)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.24, max: 68)
#
# Run: 326, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.24, max: 68)
#
# Run: 327, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.31, max: 68)
#
# Run: 328, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 23.49, max: 68)
#
# Run: 329, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 23.52, max: 68)
#
# Run: 330, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 23.52, max: 68)
#
# Run: 331, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.34, max: 68)
#
# Run: 332, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.26, max: 68)
#
# Run: 333, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.47, max: 68)
#
# Run: 334, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 23.35, max: 68)
#
# Run: 335, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 23.35, max: 68)
#
# Run: 336, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 23.73, max: 68)
#
# Run: 337, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 23.63, max: 68)
#
# Run: 338, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.63, max: 68)
#
# Run: 339, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 23.76, max: 68)
#
# Run: 340, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.69, max: 68)
#
# Run: 341, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 23.84, max: 68)
#
# Run: 342, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.4, max: 68)
#
# Run: 343, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 23.72, max: 68)
#
# Run: 344, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.72, max: 68)
#
# Run: 345, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 23.75, max: 68)
#
# Run: 346, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 23.79, max: 68)
#
# Run: 347, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 23.64, max: 68)
#
# Run: 348, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 23.64, max: 68)
#
# Run: 349, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.31, max: 68)
#
# Run: 350, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 23.89, max: 69)
#
# Run: 351, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 23.73, max: 69)
#
# Run: 352, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 24.01, max: 69)
#
# Run: 353, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.91, max: 69)
#
# Run: 354, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.13, max: 69)
#
# Run: 355, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.31, max: 69)
#
# Run: 356, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 24.51, max: 69)
#
# Run: 357, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.25, max: 69)
#
# Run: 358, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 24.56, max: 69)
#
# Run: 359, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.69, max: 69)
#
# Run: 360, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 24.73, max: 69)
#
# Run: 361, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 25.17, max: 69)
#
# Run: 362, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 25.3, max: 69)
#
# Run: 363, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 25.28, max: 69)
#
# Run: 364, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 25.27, max: 69)
#
# Run: 365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.05, max: 69)
#
# Run: 366, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.84, max: 69)
#
# Run: 367, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.73, max: 69)
#
# Run: 368, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 25.15, max: 69)
#
# Run: 369, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.9, max: 69)
#
# Run: 370, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25, max: 69)
#
# Run: 371, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.09, max: 69)
#
# Run: 372, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.06, max: 69)
#
# Run: 373, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 25.47, max: 69)
#
# Run: 374, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.43, max: 69)
#
# Run: 375, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.31, max: 69)
#
# Run: 376, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.43, max: 69)
#
# Run: 377, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 25.47, max: 69)
#
# Run: 378, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.52, max: 69)
#
# Run: 379, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 25.99, max: 69)
#
# Run: 380, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 26.07, max: 69)
#
# Run: 381, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.52, max: 69)
#
# Run: 382, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 25.49, max: 69)
#
# Run: 383, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.48, max: 69)
#
# Run: 384, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.54, max: 69)
#
# Run: 385, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.37, max: 69)
#
# Run: 386, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.36, max: 69)
#
# Run: 387, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 25.45, max: 69)
#
# Run: 388, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 25.61, max: 69)
#
# Run: 389, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 25.67, max: 69)
#
# Run: 390, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 25.82, max: 69)
#
# Run: 391, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.65, max: 69)
#
# Run: 392, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.66, max: 69)
#
# Run: 393, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 25.92, max: 69)
#
# Run: 394, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 26, max: 69)
#
# Run: 395, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.81, max: 69)
#
# Run: 396, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.79, max: 69)
#
# Run: 397, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.77, max: 69)
#
# Run: 398, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.6, max: 69)
# Run: 399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.54, max: 69)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.26, max: 69)
#
# Run: 401, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.2, max: 69)
#
# Run: 402, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.14, max: 69)
#
# Run: 403, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.88, max: 69)
#
# Run: 404, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 24.74, max: 69)
#
# Run: 405, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.52, max: 69)
#
# Run: 406, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.39, max: 69)
#
# Run: 407, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.07, max: 69)
#
# Run: 408, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.96, max: 69)
#
# Run: 409, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.85, max: 69)
#
# Run: 410, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.78, max: 69)
#
# Run: 411, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 24.22, max: 75)
#
# Run: 412, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 24.42, max: 75)
#
# Run: 413, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 24.54, max: 75)
#
# Run: 414, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 24.73, max: 75)
#
# Run: 415, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 25.02, max: 75)
#
# Run: 416, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 25.05, max: 75)
#
# Run: 417, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.98, max: 75)
#
# Run: 418, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 24.76, max: 75)
#
# Run: 419, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 24.88, max: 75)
#
# Run: 420, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 25.02, max: 75)
#
# Run: 421, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.83, max: 75)
#
# Run: 422, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 25.3, max: 75)
#
# Run: 423, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 25.09, max: 75)
#
# Run: 424, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 24.86, max: 75)
#
# Run: 425, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 24.94, max: 75)
#
# Run: 426, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 25.13, max: 75)
#
# Run: 427, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 25.27, max: 75)
#
# Run: 428, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 25.14, max: 75)
#
# Run: 429, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 25.08, max: 75)
#
# Run: 430, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 24.99, max: 75)
#
# Run: 431, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.07, max: 75)
#
# Run: 432, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 24.99, max: 75)
#
# Run: 433, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 24.98, max: 75)
#
# Run: 434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.89, max: 75)
#
# Run: 435, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.87, max: 75)
#
# Run: 436, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 24.58, max: 75)
#
# Run: 437, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 24.65, max: 75)
#
# Run: 438, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 24.77, max: 75)
#
# Run: 439, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.7, max: 75)
#
# Run: 440, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 24.78, max: 75)
#
# Run: 441, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 24.74, max: 75)
#
# Run: 442, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.81, max: 75)
#
# Run: 443, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 24.89, max: 75)
#
# Run: 444, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 24.96, max: 75)
#
# Run: 445, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 24.97, max: 75)
#
# Run: 446, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.79, max: 75)
#
# Run: 447, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.75, max: 75)
#
# Run: 448, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 24.73, max: 75)
#
# Run: 449, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.83, max: 75)
#
# Run: 450, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 24.45, max: 75)
#
# Run: 451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.41, max: 75)
#
# Run: 452, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.11, max: 75)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.04, max: 75)
#
# Run: 454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.81, max: 75)
#
# Run: 455, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.63, max: 75)
#
# Run: 456, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.38, max: 75)
#
# Run: 457, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.37, max: 75)
#
# Run: 458, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.05, max: 75)
#
# Run: 459, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.94, max: 75)
#
# Run: 460, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.88, max: 75)
#
# Run: 461, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.44, max: 75)
#
# Run: 462, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.22, max: 75)
#
# Run: 463, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.02, max: 75)
#
# Run: 464, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.8, max: 75)
#
# Run: 465, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.8, max: 75)
#
# Run: 466, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.01, max: 75)
#
# Run: 467, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 22.14, max: 75)
#
# Run: 468, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 22.27, max: 75)
#
# Run: 469, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 22.36, max: 75)
#
# Run: 470, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.41, max: 75)
#
# Run: 471, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 22.45, max: 75)
#
# Run: 472, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 22.72, max: 75)
#
# Run: 473, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.29, max: 75)
#
# Run: 474, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 22.76, max: 75)
#
# Run: 475, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.69, max: 75)
#
# Run: 476, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 22.84, max: 75)
#
# Run: 477, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 22.97, max: 75)
#
# Run: 478, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 23.14, max: 75)
#
# Run: 479, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 22.79, max: 75)
#
# Run: 480, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.68, max: 75)
#
# Run: 481, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.76, max: 75)
#
# Run: 482, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 23.05, max: 75)
#
# Run: 483, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 23.2, max: 75)
#
# Run: 484, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.06, max: 75)
#
# Run: 485, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 23.08, max: 75)
#
# Run: 486, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.04, max: 75)
#
# Run: 487, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.84, max: 75)
#
# Run: 488, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 22.74, max: 75)
#
# Run: 489, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.35, max: 75)
#
# Run: 490, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.15, max: 75)
#
# Run: 491, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 22.8, max: 77)
#
# Run: 492, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 22.92, max: 77)
#
# Run: 493, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.62, max: 77)
#
# Run: 494, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 23.44, max: 103)
#
# Run: 495, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.57, max: 103)
#
# Run: 496, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.58, max: 103)
#
# Run: 497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.6, max: 103)
#
# Run: 498, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.61, max: 103)
#
# Run: 499, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 23.75, max: 103)
#
# Run: 500, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.83, max: 103)
#
# Run: 501, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 24, max: 103)
#
# Run: 502, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.06, max: 103)
#
# Run: 503, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.06, max: 103)
#
# Run: 504, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 24.58, max: 103)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-670e42b3b2b7> in cartpole()
#      87                 score_logger.add_score(step, run)
#      88                 break
# ---> 89             dqn_solver.experience_replay()
#      90
#
# <ipython-input-3-670e42b3b2b7> in experience_replay(self)
#      55             if not terminal:
#      56                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
# ---> 57             q_values = self.model.predict(state)
#      58             q_values[0][action] = q_update
#      59             self.model.fit(state, q_values, verbose=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

# Adjusted Gamma to 0.5 from 0.95
GAMMA = 0.5  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 3, exploration: 0.9046104802746175, score: 21
# Scores: (min: 10, avg: 13.666666666666666, max: 21)
#
# Run: 4, exploration: 0.8265651079747222, score: 19
# Scores: (min: 10, avg: 15, max: 21)
#
# Run: 5, exploration: 0.7402609576967045, score: 23
# Scores: (min: 10, avg: 16.6, max: 23)
#
# Run: 6, exploration: 0.697046600835495, score: 13
# Scores: (min: 10, avg: 16, max: 23)
#
# Run: 7, exploration: 0.6498078359349755, score: 15
# Scores: (min: 10, avg: 15.857142857142858, max: 23)
#
# Run: 8, exploration: 0.6149486215357263, score: 12
# Scores: (min: 10, avg: 15.375, max: 23)
#
# Run: 9, exploration: 0.5848838636585911, score: 11
# Scores: (min: 10, avg: 14.88888888888889, max: 23)
#
# Run: 10, exploration: 0.5647174463480732, score: 8
# Scores: (min: 8, avg: 14.2, max: 23)
#
# Run: 11, exploration: 0.5264466124450268, score: 15
# Scores: (min: 8, avg: 14.272727272727273, max: 23)
#
# Run: 12, exploration: 0.4883155414435353, score: 16
# Scores: (min: 8, avg: 14.416666666666666, max: 23)
#
# Run: 13, exploration: 0.46211964903917074, score: 12
# Scores: (min: 8, avg: 14.23076923076923, max: 23)
#
# Run: 14, exploration: 0.43732904629000013, score: 12
# Scores: (min: 8, avg: 14.071428571428571, max: 23)
#
# Run: 15, exploration: 0.41386834584198684, score: 12
# Scores: (min: 8, avg: 13.933333333333334, max: 23)
#
# Run: 16, exploration: 0.39561243860243744, score: 10
# Scores: (min: 8, avg: 13.6875, max: 23)
#
# Run: 17, exploration: 0.3743896431025813, score: 12
# Scores: (min: 8, avg: 13.588235294117647, max: 23)
#
# Run: 18, exploration: 0.33362200135903064, score: 24
# Scores: (min: 8, avg: 14.166666666666666, max: 24)
#
# Run: 19, exploration: 0.31890579420988907, score: 10
# Scores: (min: 8, avg: 13.947368421052632, max: 24)
#
# Run: 20, exploration: 0.3033145315372582, score: 11
# Scores: (min: 8, avg: 13.8, max: 24)
#
# Run: 21, exploration: 0.26759021970270175, score: 26
# Scores: (min: 8, avg: 14.380952380952381, max: 26)
#
# Run: 22, exploration: 0.2570720625972084, score: 9
# Scores: (min: 8, avg: 14.136363636363637, max: 26)
#
# Run: 23, exploration: 0.2189744609715989, score: 33
# Scores: (min: 8, avg: 14.956521739130435, max: 33)
#
# Run: 24, exploration: 0.17829525136613786, score: 42
# Scores: (min: 8, avg: 16.083333333333332, max: 42)
#
# Run: 25, exploration: 0.1534024157688821, score: 31
# Scores: (min: 8, avg: 16.68, max: 42)
#
# Run: 26, exploration: 0.09672876157528969, score: 93
# Scores: (min: 8, avg: 19.615384615384617, max: 93)
#
# Run: 27, exploration: 0.0708902705368767, score: 63
# Scores: (min: 8, avg: 21.22222222222222, max: 93)
#
# Run: 28, exploration: 0.04425437624418858, score: 95
# Scores: (min: 8, avg: 23.857142857142858, max: 95)
#
# Run: 29, exploration: 0.03308985827710748, score: 59
# Scores: (min: 8, avg: 25.06896551724138, max: 95)
#
# Run: 30, exploration: 0.022494281437179946, score: 78
# Scores: (min: 8, avg: 26.833333333333332, max: 95)
#
# Run: 31, exploration: 0.013902339057518077, score: 97
# Scores: (min: 8, avg: 29.096774193548388, max: 97)
#
# Run: 32, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 30.65625, max: 97)
#
# Run: 33, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 32.18181818181818, max: 97)
#
# Run: 34, exploration: 0.01, score: 424
# Scores: (min: 8, avg: 43.705882352941174, max: 424)
#
# Run: 35, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 46.77142857142857, max: 424)
#
# Run: 36, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 49.638888888888886, max: 424)
#
# Run: 37, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 52.351351351351354, max: 424)
#
# Run: 38, exploration: 0.01, score: 337
# Scores: (min: 8, avg: 59.8421052631579, max: 424)
#
# Run: 39, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 59.41025641025641, max: 424)
#
# Run: 40, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 63.4, max: 424)
#
# Run: 41, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 67.7560975609756, max: 424)
#
# Run: 42, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 68.4047619047619, max: 424)
#
# Run: 43, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 67.09302325581395, max: 424)
#
# Run: 44, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 69.22727272727273, max: 424)
#
# Run: 45, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 70.17777777777778, max: 424)
#
# Run: 46, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 72.23913043478261, max: 424)
#
# Run: 47, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 73.17021276595744, max: 424)
#
# Run: 48, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 75.97916666666667, max: 424)
#
# Run: 49, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 77.38775510204081, max: 424)
#
# Run: 50, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 76.26, max: 424)
#
# Run: 51, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 75.11764705882354, max: 424)
#
# Run: 52, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 76.01923076923077, max: 424)
#
# Run: 53, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 77.13207547169812, max: 424)
#
# Run: 54, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 77.14814814814815, max: 424)
#
# Run: 55, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 76.4, max: 424)
#
# Run: 56, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 75.82142857142857, max: 424)
#
# Run: 57, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 75.15789473684211, max: 424)
#
# Run: 58, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 75.86206896551724, max: 424)
#
# Run: 59, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 75.01694915254237, max: 424)
#
# Run: 60, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 74.16666666666667, max: 424)
#
# Run: 61, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 73.47540983606558, max: 424)
#
# Run: 62, exploration: 0.01, score: 290
# Scores: (min: 8, avg: 76.96774193548387, max: 424)
#
# Run: 63, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 76.77777777777777, max: 424)
#
# Run: 64, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 78.40625, max: 424)
#
# Run: 65, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 79.47692307692307, max: 424)
#
# Run: 66, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 81.42424242424242, max: 424)
#
# Run: 67, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 81.68656716417911, max: 424)
#
# Run: 68, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 83.80882352941177, max: 424)
#
# Run: 69, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 84.17391304347827, max: 424)
#
# Run: 70, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 84.37142857142857, max: 424)
#
# Run: 71, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 84.77464788732394, max: 424)
#
# Run: 72, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 83.84722222222223, max: 424)
#
# Run: 73, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 83.24657534246575, max: 424)
#
# Run: 74, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 82.4054054054054, max: 424)
#
# Run: 75, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 81.50666666666666, max: 424)
#
# Run: 76, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 81.23684210526316, max: 424)
#
# Run: 77, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 81.64935064935065, max: 424)
#
# Run: 78, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 82.91025641025641, max: 424)
#
# Run: 79, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 83.24050632911393, max: 424)
#
# Run: 80, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 82.475, max: 424)
#
# Run: 81, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 81.8395061728395, max: 424)
#
# Run: 82, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 82.13414634146342, max: 424)
#
# Run: 83, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 81.89156626506023, max: 424)
#
# Run: 84, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 81.32142857142857, max: 424)
#
# Run: 85, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 81.36470588235294, max: 424)
#
# Run: 86, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 80.72093023255815, max: 424)
#
# Run: 87, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 80.75862068965517, max: 424)
#
# Run: 88, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 81.10227272727273, max: 424)
#
# Run: 89, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 81.47191011235955, max: 424)
# Run: 90, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 81.68888888888888, max: 424)
#
# Run: 91, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 81.3076923076923, max: 424)
#
# Run: 92, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 81.1304347826087, max: 424)
#
# Run: 93, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 82.02150537634408, max: 424)
#
# Run: 94, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 81.74468085106383, max: 424)
#
# Run: 95, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 81.29473684210527, max: 424)
#
# Run: 96, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 81.20833333333333, max: 424)
#
# Run: 97, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 80.65979381443299, max: 424)
#
# Run: 98, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 80.84693877551021, max: 424)
#
# Run: 99, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 81.27272727272727, max: 424)
#
# Run: 100, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 81.79, max: 424)
#
# Run: 101, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 82.1, max: 424)
#
# Run: 102, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 83.71, max: 424)
#
# Run: 103, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 83.81, max: 424)
#
# Run: 104, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 84.17, max: 424)
#
# Run: 105, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 84.9, max: 424)
#
# Run: 106, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 85.25, max: 424)
#
# Run: 107, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 86.3, max: 424)
#
# Run: 108, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 87.43, max: 424)
#
# Run: 109, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 89.98, max: 424)
#
# Run: 110, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 91.01, max: 424)
#
# Run: 111, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 92.04, max: 424)
#
# Run: 112, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 93.12, max: 424)
#
# Run: 113, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 93.5, max: 424)
#
# Run: 114, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 93.57, max: 424)
#
# Run: 115, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 94.04, max: 424)
#
# Run: 116, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 94.18, max: 424)
#
# Run: 117, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 95.96, max: 424)
#
# Run: 118, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 96.69, max: 424)
#
# Run: 119, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 97.2, max: 424)
#
# Run: 120, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 98.12, max: 424)
#
# Run: 121, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 98.39, max: 424)
#
# Run: 122, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 99.25, max: 424)
#
# Run: 123, exploration: 0.01, score: 83
# Scores: (min: 12, avg: 99.75, max: 424)
#
# Run: 124, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 99.63, max: 424)
#
# Run: 125, exploration: 0.01, score: 26
# Scores: (min: 12, avg: 99.58, max: 424)
#
# Run: 126, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 100.08, max: 424)
#
# Run: 127, exploration: 0.01, score: 204
# Scores: (min: 12, avg: 101.49, max: 424)
#
# Run: 128, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 101.32, max: 424)
#
# Run: 129, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 101.52, max: 424)
#
# Run: 130, exploration: 0.01, score: 18
# Scores: (min: 12, avg: 100.92, max: 424)
#
# Run: 131, exploration: 0.01, score: 17
# Scores: (min: 12, avg: 100.12, max: 424)
#
# Run: 132, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 100.69, max: 424)
#
# Run: 133, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 101.43, max: 424)
#
# Run: 134, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 97.97, max: 337)
#
# Run: 135, exploration: 0.01, score: 19
# Scores: (min: 12, avg: 96.65, max: 337)
#
# Run: 136, exploration: 0.01, score: 22
# Scores: (min: 12, avg: 95.37, max: 337)
#
# Run: 137, exploration: 0.01, score: 57
# Scores: (min: 12, avg: 94.44, max: 337)
#
# Run: 138, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 92.05, max: 290)
#
# Run: 139, exploration: 0.01, score: 22
# Scores: (min: 12, avg: 91.84, max: 290)
#
# Run: 140, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 90.04, max: 290)
#
# Run: 141, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 88.57, max: 290)
#
# Run: 142, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 88.82, max: 290)
#
# Run: 143, exploration: 0.01, score: 94
# Scores: (min: 15, avg: 89.64, max: 290)
#
# Run: 144, exploration: 0.01, score: 93
# Scores: (min: 15, avg: 88.96, max: 290)
#
# Run: 145, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 87.95, max: 290)
#
# Run: 146, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 86.39, max: 290)
#
# Run: 147, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 85.32, max: 290)
#
# Run: 148, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 83.33, max: 290)
#
# Run: 149, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 81.96, max: 290)
#
# Run: 150, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 81.85, max: 290)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 81.76, max: 290)
#
# Run: 152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.63, max: 290)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 79.38, max: 290)
#
# Run: 154, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 78.69, max: 290)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 78.43, max: 290)
#
# Run: 156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 78.08, max: 290)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.79, max: 290)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 76.73, max: 290)
#
# Run: 159, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 76.56, max: 290)
#
# Run: 160, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 76.42, max: 290)
#
# Run: 161, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 76.18, max: 290)
#
# Run: 162, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 73.38, max: 266)
#
# Run: 163, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 72.83, max: 266)
#
# Run: 164, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 71.12, max: 266)
#
# Run: 165, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.73, max: 266)
#
# Run: 166, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.75, max: 266)
#
# Run: 167, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.86, max: 266)
#
# Run: 168, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 64.68, max: 266)
#
# Run: 169, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 63.69, max: 266)
#
# Run: 170, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 62.81, max: 266)
#
# Run: 171, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 61.78, max: 266)
#
# Run: 172, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 61.71, max: 266)
#
# Run: 173, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 61.42, max: 266)
#
# Run: 174, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 61.3, max: 266)
#
# Run: 175, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 61.23, max: 266)
#
# Run: 176, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 60.71, max: 266)
#
# Run: 177, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 59.68, max: 266)
#
# Run: 178, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 57.98, max: 266)
#
# Run: 179, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 57, max: 266)
#
# Run: 180, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 56.87, max: 266)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 56.65, max: 266)
#
# Run: 182, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 55.68, max: 266)
#
# Run: 183, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 55.15, max: 266)
#
# Run: 184, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 54.89, max: 266)
#
# Run: 185, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 54.13, max: 266)
#
# Run: 186, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.97, max: 266)
#
# Run: 187, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.22, max: 266)
#
# Run: 188, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 52.22, max: 266)
#
# Run: 189, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.18, max: 266)
#
# Run: 190, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 50.26, max: 266)
#
# Run: 191, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.88, max: 266)
#
# Run: 192, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.32, max: 266)
# Run: 193, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.78, max: 266)
#
# Run: 194, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 47.31, max: 266)
#
# Run: 195, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 47, max: 266)
#
# Run: 196, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.36, max: 266)
#
# Run: 197, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.17, max: 266)
#
# Run: 198, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.28, max: 266)
#
# Run: 199, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 44.13, max: 266)
#
# Run: 200, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.89, max: 266)
#
# Run: 201, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.57, max: 266)
#
# Run: 202, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.96, max: 266)
#
# Run: 203, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.76, max: 266)
#
# Run: 204, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 40.9, max: 266)
#
# Run: 205, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.03, max: 266)
#
# Run: 206, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.64, max: 266)
#
# Run: 207, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.54, max: 266)
#
# Run: 208, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.39, max: 266)
#
# Run: 209, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.82, max: 204)
#
# Run: 210, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.8, max: 204)
#
# Run: 211, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 32.73, max: 204)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.59, max: 204)
#
# Run: 213, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 31.17, max: 204)
#
# Run: 214, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.07, max: 204)
#
# Run: 215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.57, max: 204)
#
# Run: 216, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.42, max: 204)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.61, max: 204)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.74, max: 204)
#
# Run: 219, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.22, max: 204)
#
# Run: 220, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.29, max: 204)
#
# Run: 221, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.85, max: 204)
#
# Run: 222, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25, max: 204)
#
# Run: 223, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.27, max: 204)
#
# Run: 224, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.07, max: 204)
#
# Run: 225, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.93, max: 204)
#
# Run: 226, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 22.62, max: 204)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.68, max: 155)
#
# Run: 228, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.99, max: 155)
#
# Run: 229, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.28, max: 155)
#
# Run: 230, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.19, max: 155)
#
# Run: 231, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.12, max: 155)
#
# Run: 232, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.85, max: 155)
#
# Run: 233, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.4, max: 120)
#
# Run: 234, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.72, max: 120)
#
# Run: 235, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.61, max: 120)
#
# Run: 236, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.47, max: 120)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.99, max: 120)
#
# Run: 238, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.18, max: 120)
#
# Run: 239, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.05, max: 120)
#
# Run: 240, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.77, max: 120)
#
# Run: 241, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.92, max: 120)
#
# Run: 242, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.93, max: 94)
#
# Run: 243, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.1, max: 93)
#
# Run: 244, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.27, max: 69)
#
# Run: 245, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.25, max: 69)
#
# Run: 246, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.25, max: 69)
#
# Run: 247, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.25, max: 69)
#
# Run: 248, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.26, max: 69)
#
# Run: 249, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 10.45, max: 69)
#
# Run: 250, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 69)
#
# Run: 251, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 10.66, max: 69)
#
# Run: 252, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.75, max: 69)
#
# Run: 253, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.78, max: 69)
#
# Run: 254, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.78, max: 69)
#
# Run: 255, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.78, max: 69)
#
# Run: 256, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.82, max: 69)
#
# Run: 257, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.83, max: 69)
#
# Run: 258, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.85, max: 69)
#
# Run: 259, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.85, max: 69)
#
# Run: 260, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11, max: 69)
#
# Run: 261, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.03, max: 69)
#
# Run: 262, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.04, max: 69)
#
# Run: 263, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.19, max: 69)
#
# Run: 264, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.19, max: 69)
#
# Run: 265, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.22, max: 69)
#
# Run: 266, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.2, max: 69)
#
# Run: 267, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.21, max: 69)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.22, max: 69)
#
# Run: 269, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.24, max: 69)
#
# Run: 270, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.27, max: 69)
#
# Run: 271, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.25, max: 69)
#
# Run: 272, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.22, max: 69)
#
# Run: 273, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.19, max: 69)
#
# Run: 274, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.2, max: 69)
#
# Run: 275, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 69)
#
# Run: 276, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.22, max: 69)
#
# Run: 277, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 69)
#
# Run: 278, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.23, max: 69)
#
# Run: 279, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.22, max: 69)
#
# Run: 280, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.21, max: 69)
#
# Run: 281, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 69)
#
# Run: 282, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.29, max: 69)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.29, max: 69)
#
# Run: 284, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.31, max: 69)
#
# Run: 285, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.32, max: 69)
#
# Run: 286, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.34, max: 69)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.34, max: 69)
#
# Run: 288, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.32, max: 69)
#
# Run: 289, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.33, max: 69)
#
# Run: 290, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.34, max: 69)
#
# Run: 291, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.33, max: 69)
#
# Run: 292, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.33, max: 69)
#
# Run: 293, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.33, max: 69)
#
# Run: 294, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.32, max: 69)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.34, max: 69)
#
# Run: 296, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.47, max: 69)
#
# Run: 297, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.46, max: 69)
#
# Run: 298, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.46, max: 69)
# Run: 299, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.6, max: 69)
#
# Run: 300, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.64, max: 69)
#
# Run: 301, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.65, max: 69)
#
# Run: 302, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.64, max: 69)
#
# Run: 303, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.62, max: 69)
#
# Run: 304, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.01, max: 30)
#
# Run: 305, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.05, max: 30)
#
# Run: 306, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.11, max: 30)
#
# Run: 307, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 30)
#
# Run: 308, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 30)
#
# Run: 309, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.23, max: 30)
#
# Run: 310, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.23, max: 30)
#
# Run: 311, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.26, max: 30)
#
# Run: 312, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.25, max: 30)
#
# Run: 313, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.29, max: 30)
#
# Run: 314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.29, max: 30)
#
# Run: 315, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.31, max: 30)
#
# Run: 316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.31, max: 30)
#
# Run: 317, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.33, max: 30)
#
# Run: 318, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.43, max: 30)
#
# Run: 319, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.45, max: 30)
#
# Run: 320, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.45, max: 30)
#
# Run: 321, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 30)
#
# Run: 322, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.43, max: 30)
#
# Run: 323, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.41, max: 30)
#
# Run: 324, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.41, max: 30)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.38, max: 30)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.35, max: 30)
#
# Run: 327, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.34, max: 30)
#
# Run: 328, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.33, max: 30)
#
# Run: 329, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.36, max: 30)
#
# Run: 330, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.37, max: 30)
#
# Run: 331, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.39, max: 30)
#
# Run: 332, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 30)
#
# Run: 333, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.44, max: 30)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.44, max: 30)
#
# Run: 335, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 30)
#
# Run: 336, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.6, max: 30)
#
# Run: 337, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.63, max: 30)
#
# Run: 338, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.56, max: 30)
#
# Run: 339, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.57, max: 30)
#
# Run: 340, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.55, max: 30)
#
# Run: 341, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.56, max: 30)
#
# Run: 342, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.44, max: 30)
#
# Run: 343, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.42, max: 30)
#
# Run: 344, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.42, max: 30)
#
# Run: 345, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.46, max: 30)
#
# Run: 346, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.47, max: 30)
#
# Run: 347, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.46, max: 30)
#
# Run: 348, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 30)
#
# Run: 349, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.31, max: 30)
#
# Run: 350, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.31, max: 30)
#
# Run: 351, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 25)
#
# Run: 352, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.18, max: 25)
#
# Run: 353, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.14, max: 25)
#
# Run: 354, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.13, max: 25)
#
# Run: 355, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.13, max: 25)
#
# Run: 356, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.11, max: 25)
#
# Run: 357, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.13, max: 25)
#
# Run: 358, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.1, max: 25)
#
# Run: 359, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.1, max: 25)
#
# Run: 360, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.95, max: 25)
#
# Run: 361, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.93, max: 25)
#
# Run: 362, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.94, max: 25)
#
# Run: 363, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.78, max: 25)
#
# Run: 364, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.77, max: 25)
#
# Run: 365, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.73, max: 25)
#
# Run: 366, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.74, max: 25)
#
# Run: 367, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.72, max: 25)
#
# Run: 368, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.73, max: 25)
#
# Run: 369, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.7, max: 25)
#
# Run: 370, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.66, max: 25)
#
# Run: 371, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.73, max: 25)
#
# Run: 372, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.74, max: 25)
#
# Run: 373, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.76, max: 25)
#
# Run: 374, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 10.94, max: 28)
#
# Run: 375, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.95, max: 28)
#
# Run: 376, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.95, max: 28)
#
# Run: 377, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.96, max: 28)
#
# Run: 378, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.92, max: 28)
#
# Run: 379, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.02, max: 28)
#
# Run: 380, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.04, max: 28)
#
# Run: 381, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.04, max: 28)
#
# Run: 382, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.99, max: 28)
#
# Run: 383, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11, max: 28)
#
# Run: 384, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.99, max: 28)
#
# Run: 385, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.99, max: 28)
#
# Run: 386, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.02, max: 28)
#
# Run: 387, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 11.23, max: 30)
#
# Run: 388, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.23, max: 30)
#
# Run: 389, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 30)
#
# Run: 390, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.2, max: 30)
#
# Run: 391, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 30)
#
# Run: 392, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.32, max: 30)
#
# Run: 393, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.44, max: 30)
#
# Run: 394, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.51, max: 30)
#
# Run: 395, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.51, max: 30)
#
# Run: 396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.39, max: 30)
#
# Run: 397, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.39, max: 30)
#
# Run: 398, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.38, max: 30)
#
# Run: 399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.26, max: 30)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.22, max: 30)
#
# Run: 401, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 30)
#
# Run: 402, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 30)
#
# Run: 403, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.27, max: 30)
#
# Run: 404, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.28, max: 30)
# Run: 405, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.33, max: 30)
#
# Run: 406, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.28, max: 30)
#
# Run: 407, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.28, max: 30)
#
# Run: 408, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.26, max: 30)
#
# Run: 409, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.14, max: 30)
#
# Run: 410, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 11.32, max: 30)
#
# Run: 411, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.28, max: 30)
#
# Run: 412, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.27, max: 30)
#
# Run: 413, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.25, max: 30)
#
# Run: 414, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.35, max: 30)
#
# Run: 415, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.33, max: 30)
#
# Run: 416, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.34, max: 30)
#
# Run: 417, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.32, max: 30)
#
# Run: 418, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.27, max: 30)
#
# Run: 419, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.36, max: 30)
#
# Run: 420, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.36, max: 30)
#
# Run: 421, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.38, max: 30)
#
# Run: 422, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.41, max: 30)
#
# Run: 423, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.41, max: 30)
#
# Run: 424, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.47, max: 30)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.48, max: 30)
#
# Run: 426, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.48, max: 30)
#
# Run: 427, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.51, max: 30)
#
# Run: 428, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 11.72, max: 30)
#
# Run: 429, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.71, max: 30)
#
# Run: 430, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.75, max: 30)
#
# Run: 431, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 12.04, max: 41)
#
# Run: 432, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.04, max: 41)
#
# Run: 433, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12, max: 41)
#
# Run: 434, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.17, max: 41)
#
# Run: 435, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.2, max: 41)
#
# Run: 436, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.06, max: 41)
#
# Run: 437, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.03, max: 41)
#
# Run: 438, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.05, max: 41)
#
# Run: 439, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.03, max: 41)
#
# Run: 440, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.04, max: 41)
#
# Run: 441, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.09, max: 41)
#
# Run: 442, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.16, max: 41)
#
# Run: 443, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.18, max: 41)
#
# Run: 444, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.17, max: 41)
#
# Run: 445, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.14, max: 41)
#
# Run: 446, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.22, max: 41)
#
# Run: 447, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.25, max: 41)
#
# Run: 448, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.27, max: 41)
#
# Run: 449, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.38, max: 41)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.37, max: 41)
#
# Run: 451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.36, max: 41)
#
# Run: 452, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.21, max: 41)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.22, max: 41)
#
# Run: 454, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.23, max: 41)
#
# Run: 455, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.21, max: 41)
#
# Run: 456, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.28, max: 41)
#
# Run: 457, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.24, max: 41)
#
# Run: 458, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.31, max: 41)
#
# Run: 459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.32, max: 41)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.32, max: 41)
#
# Run: 461, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.33, max: 41)
#
# Run: 462, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.3, max: 41)
#
# Run: 463, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.3, max: 41)
#
# Run: 464, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.3, max: 41)
#
# Run: 465, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.32, max: 41)
#
# Run: 466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.33, max: 41)
#
# Run: 467, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.33, max: 41)
#
# Run: 468, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.35, max: 41)
#
# Run: 469, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.35, max: 41)
#
# Run: 470, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.36, max: 41)
#
# Run: 471, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.31, max: 41)
#
# Run: 472, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.32, max: 41)
#
# Run: 473, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.33, max: 41)
#
# Run: 474, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.13, max: 41)
#
# Run: 475, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.13, max: 41)
#
# Run: 476, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.12, max: 41)
#
# Run: 477, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.13, max: 41)
#
# Run: 478, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.13, max: 41)
#
# Run: 479, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.03, max: 41)
#
# Run: 480, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.01, max: 41)
#
# Run: 481, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.08, max: 41)
#
# Run: 482, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.04, max: 41)
#
# Run: 483, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.03, max: 41)
#
# Run: 484, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.09, max: 41)
#
# Run: 485, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.07, max: 41)
#
# Run: 486, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.01, max: 41)
#
# Run: 487, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.81, max: 41)
#
# Run: 488, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.82, max: 41)
#
# Run: 489, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.83, max: 41)
#
# Run: 490, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.9, max: 41)
#
# Run: 491, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.99, max: 41)
#
# Run: 492, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.93, max: 41)
#
# Run: 493, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.8, max: 41)
#
# Run: 494, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.75, max: 41)
#
# Run: 495, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.76, max: 41)
#
# Run: 496, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.82, max: 41)
#
# Run: 497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.84, max: 41)
#
# Run: 498, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.85, max: 41)
#
# Run: 499, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.85, max: 41)
#
# Run: 500, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.84, max: 41)
#
# Run: 501, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.92, max: 41)
#
# Run: 502, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.98, max: 41)
#
# Run: 503, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.97, max: 41)
#
# Run: 504, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.97, max: 41)
#
# Run: 505, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.89, max: 41)
#
# Run: 506, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.88, max: 41)
#
# Run: 507, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.88, max: 41)
#
# Run: 508, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.01, max: 41)
#
# Run: 509, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.01, max: 41)
#
# Run: 510, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.84, max: 41)
# Run: 511, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.82, max: 41)
#
# Run: 512, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12, max: 41)
#
# Run: 513, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.01, max: 41)
#
# Run: 514, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.92, max: 41)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.93, max: 41)
#
# Run: 516, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.91, max: 41)
#
# Run: 517, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.92, max: 41)
#
# Run: 518, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.87, max: 41)
#
# Run: 519, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.76, max: 41)
#
# Run: 520, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.75, max: 41)
#
# Run: 521, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.73, max: 41)
#
# Run: 522, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.72, max: 41)
#
# Run: 523, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.76, max: 41)
#
# Run: 524, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.7, max: 41)
#
# Run: 525, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.7, max: 41)
#
# Run: 526, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.86, max: 41)
#
# Run: 527, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.83, max: 41)
#
# Run: 528, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.64, max: 41)
#
# Run: 529, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.74, max: 41)
#
# Run: 530, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.7, max: 41)
#
# Run: 531, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.39, max: 27)
#
# Run: 532, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.53, max: 27)
#
# Run: 533, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.51, max: 27)
#
# Run: 534, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.32, max: 26)
#
# Run: 535, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.3, max: 26)
#
# Run: 536, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.38, max: 26)
#
# Run: 537, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.38, max: 26)
#
# Run: 538, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.51, max: 26)
#
# Run: 539, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.53, max: 26)
#
# Run: 540, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.53, max: 26)
#
# Run: 541, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.47, max: 26)
#
# Run: 542, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 543, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.42, max: 26)
#
# Run: 544, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.43, max: 26)
#
# Run: 545, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.45, max: 26)
#
# Run: 546, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.37, max: 26)
#
# Run: 547, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 548, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 26)
#
# Run: 549, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.26, max: 26)
#
# Run: 550, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 551, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 552, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 553, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.43, max: 26)
#
# Run: 554, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.44, max: 26)
#
# Run: 555, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 26)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.37, max: 26)
#
# Run: 557, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.39, max: 26)
#
# Run: 558, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.32, max: 26)
#
# Run: 559, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.37, max: 26)
#
# Run: 560, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.36, max: 26)
#
# Run: 561, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.36, max: 26)
#
# Run: 562, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.37, max: 26)
#
# Run: 563, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 564, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 565, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.4, max: 26)
#
# Run: 566, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.39, max: 26)
#
# Run: 567, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 26)
#
# Run: 568, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.37, max: 26)
#
# Run: 569, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.36, max: 26)
#
# Run: 570, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.37, max: 26)
#
# Run: 571, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.36, max: 26)
#
# Run: 572, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.36, max: 26)
#
# Run: 573, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.34, max: 26)
#
# Run: 574, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.34, max: 26)
#
# Run: 575, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.33, max: 26)
#
# Run: 576, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.34, max: 26)
#
# Run: 577, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.33, max: 26)
#
# Run: 578, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.35, max: 26)
#
# Run: 579, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.36, max: 26)
#
# Run: 580, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.38, max: 26)
#
# Run: 581, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.31, max: 26)
#
# Run: 582, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.44, max: 26)
#
# Run: 583, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.46, max: 26)
#
# Run: 584, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.4, max: 26)
#
# Run: 585, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.41, max: 26)
#
# Run: 586, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.54, max: 26)
#
# Run: 587, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.53, max: 26)
#
# Run: 588, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.52, max: 26)
#
# Run: 589, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.51, max: 26)
#
# Run: 590, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.6, max: 26)
#
# Run: 591, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.52, max: 26)
#
# Run: 592, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.6, max: 26)
#
# Run: 593, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.6, max: 26)
#
# Run: 594, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.61, max: 26)
#
# Run: 595, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.64, max: 26)
#
# Run: 596, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.66, max: 26)
#
# Run: 597, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.65, max: 26)
#
# Run: 598, exploration: 0.01, score: 14
# ...
# Scores: (min: 8, avg: 12.56, max: 51)
# Run: 1356, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.42, max: 51)
#
# Run: 1357, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.14, max: 51)
#
# Run: 1358, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.12, max: 51)
#
# Run: 1359, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 12.42, max: 51)
#
# Run: 1360, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.3, max: 51)
#
# Run: 1361, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.31, max: 51)
#
# Run: 1362, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.32, max: 51)
#
# Run: 1363, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.33, max: 51)
#
# Run: 1364, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.34, max: 51)
#
# Run: 1365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.33, max: 51)
#
# Run: 1366, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.26, max: 51)
#
# Run: 1367, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.25, max: 51)
#
# Run: 1368, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.24, max: 51)
#
# Run: 1369, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.27, max: 51)
#
# Run: 1370, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.4, max: 51)
#
# Run: 1371, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.54, max: 51)
#
# Run: 1372, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.38, max: 51)
#
# Run: 1373, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.4, max: 51)
#
# Run: 1374, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.41, max: 51)
#
# Run: 1375, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.41, max: 51)
#
# Run: 1376, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.4, max: 51)
#
# Run: 1377, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.31, max: 51)
#
# Run: 1378, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.29, max: 51)
#
# Run: 1379, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.28, max: 51)
#
# Run: 1380, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.2, max: 51)
#
# Run: 1381, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.2, max: 51)
#
# Run: 1382, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.19, max: 51)
#
# Run: 1383, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.18, max: 51)
#
# Run: 1384, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.16, max: 51)
#
# Run: 1385, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.16, max: 51)
#
# Run: 1386, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.01, max: 51)
#
# Run: 1387, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.9, max: 51)
#
# Run: 1388, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.82, max: 51)
#
# Run: 1389, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.82, max: 51)
#
# Run: 1390, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.82, max: 51)
#
# Run: 1391, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.83, max: 51)
#
# Run: 1392, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.88, max: 51)
#
# Run: 1393, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.8, max: 51)
#
# Run: 1394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.79, max: 51)
#
# Run: 1395, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.7, max: 51)
#
# Run: 1396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.7, max: 51)
#
# Run: 1397, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.77, max: 51)
#
# Run: 1398, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.77, max: 51)
#
# Run: 1399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.78, max: 51)
#
# Run: 1400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.77, max: 51)
#
# Run: 1401, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.58, max: 51)
#
# Run: 1402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.17, max: 40)
#
# Run: 1403, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.18, max: 40)
#
# Run: 1404, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.17, max: 40)
#
# Run: 1405, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.18, max: 40)
#
# Run: 1406, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.16, max: 40)
#
# Run: 1407, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.18, max: 40)
#
# Run: 1408, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.2, max: 40)
#
# Run: 1409, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.09, max: 40)
#
# Run: 1410, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.05, max: 40)
#
# Run: 1411, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.06, max: 40)
#
# Run: 1412, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.06, max: 40)
#
# Run: 1413, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.04, max: 40)
#
# Run: 1414, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.08, max: 40)
#
# Run: 1415, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.07, max: 40)
#
# Run: 1416, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.1, max: 40)
#
# Run: 1417, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.22, max: 40)
#
# Run: 1418, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.22, max: 40)
#
# Run: 1419, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.32, max: 40)
#
# Run: 1420, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.32, max: 40)
#
# Run: 1421, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.33, max: 40)
#
# Run: 1422, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.33, max: 40)
#
# Run: 1423, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.36, max: 40)
#
# Run: 1424, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.17, max: 40)
#
# Run: 1425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.18, max: 40)
#
# Run: 1426, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.18, max: 40)
#
# Run: 1427, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.18, max: 40)
#
# Run: 1428, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.19, max: 40)
#
# Run: 1429, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.21, max: 40)
#
# Run: 1430, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.27, max: 40)
#
# Run: 1431, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.28, max: 40)
#
# Run: 1432, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.39, max: 40)
#
# Run: 1433, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.34, max: 40)
#
# Run: 1434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.24, max: 40)
#
# Run: 1435, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.25, max: 40)
#
# Run: 1436, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.26, max: 40)
#
# Run: 1437, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 11.52, max: 40)
#
# Run: 1438, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.36, max: 40)
#
# Run: 1439, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.31, max: 40)
#
# Run: 1440, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.45, max: 40)
#
# Run: 1441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.46, max: 40)
#
# Run: 1442, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 40)
#
# Run: 1443, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.46, max: 40)
#
# Run: 1444, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 40)
#
# Run: 1445, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.44, max: 40)
#
# Run: 1446, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.34, max: 40)
#
# Run: 1447, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.44, max: 40)
#
# Run: 1448, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.43, max: 40)
#
# Run: 1449, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.38, max: 40)
#
# Run: 1450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.38, max: 40)
#
# Run: 1451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.37, max: 40)
#
# Run: 1452, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.37, max: 40)
#
# Run: 1453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.39, max: 40)
#
# Run: 1454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 40)
#
# Run: 1455, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 40)
#
# Run: 1456, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.38, max: 40)
#
# Run: 1457, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.41, max: 40)
#
# Run: 1458, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.41, max: 40)
#
# Run: 1459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 35)
#
# Run: 1460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 35)
# Run: 1461, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 35)
#
# Run: 1462, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 35)
#
# Run: 1463, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.1, max: 35)
#
# Run: 1464, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.1, max: 35)
#
# Run: 1465, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.13, max: 35)
#
# Run: 1466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.14, max: 35)
#
# Run: 1467, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.15, max: 35)
#
# Run: 1468, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.17, max: 35)
#
# Run: 1469, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.13, max: 35)
#
# Run: 1470, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.02, max: 35)
#
# Run: 1471, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.87, max: 35)
#
# Run: 1472, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.87, max: 35)
#
# Run: 1473, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.87, max: 35)
#
# Run: 1474, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 10.96, max: 35)
#
# Run: 1475, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.96, max: 35)
#
# Run: 1476, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.98, max: 35)
#
# Run: 1477, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.99, max: 35)
#
# Run: 1478, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11, max: 35)
#
# Run: 1479, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11, max: 35)
#
# Run: 1480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11, max: 35)
#
# Run: 1481, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.94, max: 35)
#
# Run: 1482, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.93, max: 35)
#
# Run: 1483, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11, max: 35)
#
# Run: 1484, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11, max: 35)
#
# Run: 1485, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.01, max: 35)
#
# Run: 1486, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.08, max: 35)
#
# Run: 1487, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.06, max: 35)
#
# Run: 1488, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.03, max: 35)
#
# Run: 1489, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.03, max: 35)
#
# Run: 1490, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.01, max: 35)
#
# Run: 1491, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.99, max: 35)
#
# Run: 1492, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.93, max: 35)
#
# Run: 1493, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.93, max: 35)
#
# Run: 1494, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.94, max: 35)
#
# Run: 1495, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.93, max: 35)
#
# Run: 1496, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 11.1, max: 35)
#
# Run: 1497, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.2, max: 35)
#
# Run: 1498, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.22, max: 35)
#
# Run: 1499, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 35)
#
# Run: 1500, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.2, max: 35)
#
# Run: 1501, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.19, max: 35)
#
# Run: 1502, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.25, max: 35)
#
# Run: 1503, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.38, max: 35)
#
# Run: 1504, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 35)
#
# Run: 1505, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.49, max: 35)
#
# Run: 1506, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.48, max: 35)
#
# Run: 1507, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.46, max: 35)
#
# Run: 1508, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.45, max: 35)
#
# Run: 1509, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 35)
#
# Run: 1510, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.46, max: 35)
#
# Run: 1511, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.47, max: 35)
#
# Run: 1512, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.46, max: 35)
#
# Run: 1513, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.52, max: 35)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-670e42b3b2b7> in cartpole()
#      87                 score_logger.add_score(step, run)
#      88                 break
# ---> 89             dqn_solver.experience_replay()
#      90
#
# <ipython-input-3-670e42b3b2b7> in experience_replay(self)
#      57             q_values = self.model.predict(state)
#      58             q_values[0][action] = q_update
# ---> 59             self.model.fit(state, q_values, verbose=0)
#      60         self.exploration_rate *= EXPLORATION_DECAY
#      61         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     190                                     'pass shuffle="batch".')
#     191                 batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
# --> 192                 callbacks._call_batch_hook('train', 'begin', batch_index, batch_logs)
#     193                 for i in indices_for_conversion_to_dense:
#     194                     ins_batch[i] = ins_batch[i].toarray()
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#      86         self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#      87
# ---> 88         delta_t_median = np.median(self._delta_ts[hook_name])
#      89         if (self._delta_t_batch > 0. and
#      90            delta_t_median > 0.95 * self._delta_t_batch and
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3495     """
#    3496     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3497                     overwrite_input=overwrite_input)
#    3498     if keepdims:
#    3499         return r.reshape(k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3403         keepdim = (1,) * a.ndim
#    3404
# -> 3405     r = func(a, **kwargs)
#    3406     return r, keepdim
#    3407
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    3528             part = a
#    3529     else:
# -> 3530         part = partition(a, kth, axis=axis)
#    3531
#    3532     if part.shape == ():
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in partition(a, kth, axis, kind, order)
#     732     else:
#     733         a = asanyarray(a).copy(order="K")
# --> 734     a.partition(kth, axis=axis, kind=kind, order=order)
#     735     return a
#     736
#
# KeyboardInterrupt:

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
# Adjusted exploration decay to .605 from .995
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.605  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9752487531218751, score: 25
# Scores: (min: 25, avg: 25, max: 25)
#
# Run: 2, exploration: 0.9275689688183278, score: 11
# Scores: (min: 11, avg: 18, max: 25)
#
# Run: 3, exploration: 0.8142285204175609, score: 27
# Scores: (min: 11, avg: 21, max: 27)
#
# Run: 4, exploration: 0.736559652908221, score: 21
# Scores: (min: 11, avg: 21, max: 27)
#
# Run: 5, exploration: 0.6935613678313175, score: 13
# Scores: (min: 11, avg: 19.4, max: 27)
#
# Run: 6, exploration: 0.6629680834613705, score: 10
# Scores: (min: 10, avg: 17.833333333333332, max: 27)
#
# Run: 7, exploration: 0.6088145090359074, score: 18
# Scores: (min: 10, avg: 17.857142857142858, max: 27)
#
# Run: 8, exploration: 0.5590843898207511, score: 18
# Scores: (min: 10, avg: 17.875, max: 27)
#
# Run: 9, exploration: 0.5238143793828016, score: 14
# Scores: (min: 10, avg: 17.444444444444443, max: 27)
#
# Run: 10, exploration: 0.4982051627146237, score: 11
# Scores: (min: 10, avg: 16.8, max: 27)
#
# Run: 11, exploration: 0.46677573701590436, score: 14
# Scores: (min: 10, avg: 16.545454545454547, max: 27)
#
# Run: 12, exploration: 0.4351424010585501, score: 15
# Scores: (min: 10, avg: 16.416666666666668, max: 27)
#
# Run: 13, exploration: 0.4159480862733536, score: 10
# Scores: (min: 10, avg: 15.923076923076923, max: 27)
#
# Run: 14, exploration: 0.4016064652978155, score: 8
# Scores: (min: 8, avg: 15.357142857142858, max: 27)
#
# Run: 15, exploration: 0.3877593341372176, score: 8
# Scores: (min: 8, avg: 14.866666666666667, max: 27)
#
# Run: 16, exploration: 0.33698341088258443, score: 29
# Scores: (min: 8, avg: 15.75, max: 29)
#
# Run: 17, exploration: 0.32050833588933575, score: 11
# Scores: (min: 8, avg: 15.470588235294118, max: 29)
#
# Run: 18, exploration: 0.3033145315372582, score: 12
# Scores: (min: 8, avg: 15.277777777777779, max: 29)
#
# Run: 19, exploration: 0.2913921604631864, score: 9
# Scores: (min: 8, avg: 14.947368421052632, max: 29)
#
# Run: 20, exploration: 0.27853872940185365, score: 10
# Scores: (min: 8, avg: 14.7, max: 29)
#
# Run: 21, exploration: 0.2649210072611673, score: 11
# Scores: (min: 8, avg: 14.523809523809524, max: 29)
#
# Run: 22, exploration: 0.2532352299289372, score: 10
# Scores: (min: 8, avg: 14.318181818181818, max: 29)
#
# Run: 23, exploration: 0.2384520680152932, score: 13
# Scores: (min: 8, avg: 14.26086956521739, max: 29)
#
# Run: 24, exploration: 0.21355457002808648, score: 23
# Scores: (min: 8, avg: 14.625, max: 29)
#
# Run: 25, exploration: 0.1756341724525918, score: 40
# Scores: (min: 8, avg: 15.64, max: 40)
#
# Run: 26, exploration: 0.13264825480308728, score: 57
# Scores: (min: 8, avg: 17.23076923076923, max: 57)
#
# Run: 27, exploration: 0.1176130407830293, score: 25
# Scores: (min: 8, avg: 17.51851851851852, max: 57)
#
# Run: 28, exploration: 0.10018300685223579, score: 33
# Scores: (min: 8, avg: 18.071428571428573, max: 57)
#
# Run: 29, exploration: 0.09576389217857617, score: 10
# Scores: (min: 8, avg: 17.79310344827586, max: 57)
#
# Run: 30, exploration: 0.08706434220766679, score: 20
# Scores: (min: 8, avg: 17.866666666666667, max: 57)
#
# Run: 31, exploration: 0.07955285615946175, score: 19
# Scores: (min: 8, avg: 17.903225806451612, max: 57)
#
# Run: 32, exploration: 0.07490878371492794, score: 13
# Scores: (min: 8, avg: 17.75, max: 57)
#
# Run: 33, exploration: 0.06641813604822402, score: 25
# Scores: (min: 8, avg: 17.96969696969697, max: 57)
#
# Run: 34, exploration: 0.058889873488111255, score: 25
# Scores: (min: 8, avg: 18.176470588235293, max: 57)
#
# Run: 35, exploration: 0.05601075525639029, score: 11
# Scores: (min: 8, avg: 17.97142857142857, max: 57)
#
# Run: 36, exploration: 0.053006034755694834, score: 12
# Scores: (min: 8, avg: 17.805555555555557, max: 57)
#
# Run: 37, exploration: 0.0451506389749415, score: 33
# Scores: (min: 8, avg: 18.216216216216218, max: 57)
#
# Run: 38, exploration: 0.04272851397543923, score: 12
# Scores: (min: 8, avg: 18.05263157894737, max: 57)
#
# Run: 39, exploration: 0.04043632488927963, score: 12
# Scores: (min: 8, avg: 17.897435897435898, max: 57)
#
# Run: 40, exploration: 0.03694767635022522, score: 19
# Scores: (min: 8, avg: 17.925, max: 57)
#
# Run: 41, exploration: 0.03275978694079333, score: 25
# Scores: (min: 8, avg: 18.097560975609756, max: 57)
#
# Run: 42, exploration: 0.030847362533106718, score: 13
# Scores: (min: 8, avg: 17.976190476190474, max: 57)
#
# Run: 43, exploration: 0.029339239003388088, score: 11
# Scores: (min: 8, avg: 17.813953488372093, max: 57)
#
# Run: 44, exploration: 0.027765323199097504, score: 12
# Scores: (min: 8, avg: 17.681818181818183, max: 57)
#
# Run: 45, exploration: 0.025754252208694463, score: 16
# Scores: (min: 8, avg: 17.644444444444446, max: 57)
#
# Run: 46, exploration: 0.023650553933395897, score: 18
# Scores: (min: 8, avg: 17.652173913043477, max: 57)
#
# Run: 47, exploration: 0.022158551474944856, score: 14
# Scores: (min: 8, avg: 17.574468085106382, max: 57)
#
# Run: 48, exploration: 0.020553584742122436, score: 16
# Scores: (min: 8, avg: 17.541666666666668, max: 57)
#
# Run: 49, exploration: 0.018686420266267767, score: 20
# Scores: (min: 8, avg: 17.591836734693878, max: 57)
#
# Run: 50, exploration: 0.01615829206087557, score: 30
# Scores: (min: 8, avg: 17.84, max: 57)
#
# Run: 51, exploration: 0.014987930304771725, score: 16
# Scores: (min: 8, avg: 17.80392156862745, max: 57)
#
# Run: 52, exploration: 0.014042412118399107, score: 14
# Scores: (min: 8, avg: 17.73076923076923, max: 57)
#
# Run: 53, exploration: 0.011782828070678488, score: 36
# Scores: (min: 8, avg: 18.07547169811321, max: 57)
#
# Run: 54, exploration: 0.010874738754866477, score: 17
# Scores: (min: 8, avg: 18.055555555555557, max: 57)
#
# Run: 55, exploration: 0.010087070213020206, score: 16
# Scores: (min: 8, avg: 18.01818181818182, max: 57)
#
# Run: 56, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.035714285714285, max: 57)
#
# Run: 57, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.210526315789473, max: 57)
#
# Run: 58, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.086206896551722, max: 57)
#
# Run: 59, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.135593220338983, max: 57)
#
# Run: 60, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.35, max: 57)
#
# Run: 61, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.459016393442624, max: 57)
#
# Run: 62, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.467741935483872, max: 57)
#
# Run: 63, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.365079365079364, max: 57)
#
# Run: 64, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 18.75, max: 57)
#
# Run: 65, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 19.415384615384614, max: 62)
#
# Run: 66, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 19.545454545454547, max: 62)
#
# Run: 67, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 20.880597014925375, max: 109)
#
# Run: 68, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 21.073529411764707, max: 109)
#
# Run: 69, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 21.768115942028984, max: 109)
#
# Run: 70, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 22.242857142857144, max: 109)
#
# Run: 71, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 22.6056338028169, max: 109)
#
# Run: 72, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 22.63888888888889, max: 109)
#
# Run: 73, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.534246575342465, max: 109)
#
# Run: 74, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 22.986486486486488, max: 109)
#
# Run: 75, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 23.346666666666668, max: 109)
#
# Run: 76, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 23.644736842105264, max: 109)
#
# Run: 77, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 24.051948051948052, max: 109)
#
# Run: 78, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 24.333333333333332, max: 109)
#
# Run: 79, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 24.810126582278482, max: 109)
#
# Run: 80, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 25.2, max: 109)
#
# Run: 81, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 25.34567901234568, max: 109)
#
# Run: 82, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 25.70731707317073, max: 109)
#
# Run: 83, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 26.03614457831325, max: 109)
#
# Run: 84, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 26.30952380952381, max: 109)
#
# Run: 85, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 26.470588235294116, max: 109)
# Run: 86, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 26.930232558139537, max: 109)
#
# Run: 87, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 27.862068965517242, max: 109)
#
# Run: 88, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 28.443181818181817, max: 109)
#
# Run: 89, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 28.9438202247191, max: 109)
#
# Run: 90, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 29.455555555555556, max: 109)
#
# Run: 91, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 29.296703296703296, max: 109)
#
# Run: 92, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 29.32608695652174, max: 109)
#
# Run: 93, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 29.301075268817204, max: 109)
#
# Run: 94, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 29.20212765957447, max: 109)
#
# Run: 95, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 30.221052631578946, max: 126)
#
# Run: 96, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 30.84375, max: 126)
#
# Run: 97, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 31.54639175257732, max: 126)
#
# Run: 98, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.316326530612244, max: 126)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.09090909090909, max: 126)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.87, max: 126)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.72, max: 126)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.71, max: 126)
#
# Run: 103, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.52, max: 126)
#
# Run: 104, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.39, max: 126)
#
# Run: 105, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.37, max: 126)
#
# Run: 106, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.36, max: 126)
#
# Run: 107, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.26, max: 126)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.17, max: 126)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.13, max: 126)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.12, max: 126)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.08, max: 126)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.03, max: 126)
#
# Run: 113, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.03, max: 126)
#
# Run: 114, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.06, max: 126)
#
# Run: 115, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.08, max: 126)
#
# Run: 116, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.88, max: 126)
#
# Run: 117, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.88, max: 126)
#
# Run: 118, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.86, max: 126)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.87, max: 126)
#
# Run: 120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.87, max: 126)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.86, max: 126)
#
# Run: 122, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.87, max: 126)
#
# Run: 123, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.84, max: 126)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.7, max: 126)
#
# Run: 125, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.39, max: 126)
#
# Run: 126, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.91, max: 126)
#
# Run: 127, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.74, max: 126)
#
# Run: 128, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.5, max: 126)
#
# Run: 129, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.5, max: 126)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.4, max: 126)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.3, max: 126)
#
# Run: 132, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.26, max: 126)
#
# Run: 133, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.1, max: 126)
#
# Run: 134, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.93, max: 126)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.92, max: 126)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.89, max: 126)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.66, max: 126)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.63, max: 126)
#
# Run: 139, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 27.63, max: 126)
#
# Run: 140, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 27.56, max: 126)
#
# Run: 141, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.39, max: 126)
#
# Run: 142, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.34, max: 126)
#
# Run: 143, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.33, max: 126)
#
# Run: 144, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.29, max: 126)
#
# Run: 145, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.22, max: 126)
#
# Run: 146, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.14, max: 126)
#
# Run: 147, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 27.12, max: 126)
#
# Run: 148, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.07, max: 126)
#
# Run: 149, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.01, max: 126)
#
# Run: 150, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 26.94, max: 126)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.87, max: 126)
#
# Run: 152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.82, max: 126)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.56, max: 126)
#
# Run: 154, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.48, max: 126)
#
# Run: 155, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.41, max: 126)
#
# Run: 156, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 26.33, max: 126)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.14, max: 126)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.13, max: 126)
#
# Run: 159, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 26.03, max: 126)
#
# Run: 160, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.82, max: 126)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.67, max: 126)
#
# Run: 162, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.57, max: 126)
#
# Run: 163, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 25.61, max: 126)
#
# Run: 164, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 25.34, max: 126)
#
# Run: 165, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.87, max: 126)
#
# Run: 166, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.74, max: 126)
#
# Run: 167, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.85, max: 126)
#
# Run: 168, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.65, max: 126)
#
# Run: 169, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.13, max: 126)
#
# Run: 170, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 22.75, max: 126)
#
# Run: 171, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 22.43, max: 126)
#
# Run: 172, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 22.38, max: 126)
#
# Run: 173, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 22.4, max: 126)
#
# Run: 174, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.02, max: 126)
#
# Run: 175, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.65, max: 126)
#
# Run: 176, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 21.34, max: 126)
#
# Run: 177, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.94, max: 126)
#
# Run: 178, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.6, max: 126)
#
# Run: 179, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.09, max: 126)
#
# Run: 180, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.66, max: 126)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.38, max: 126)
#
# Run: 182, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.93, max: 126)
#
# Run: 183, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.52, max: 126)
#
# Run: 184, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.13, max: 126)
#
# Run: 185, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.87, max: 126)
#
# Run: 186, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.33, max: 126)
#
# Run: 187, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.34, max: 126)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.65, max: 126)
# Run: 189, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.01, max: 126)
#
# Run: 190, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.35, max: 126)
#
# Run: 191, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.31, max: 126)
#
# Run: 192, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.09, max: 126)
#
# Run: 193, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.93, max: 126)
#
# Run: 194, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.82, max: 126)
#
# Run: 195, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.66, max: 99)
#
# Run: 196, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.86, max: 99)
#
# Run: 197, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 198, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 199, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 200, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 201, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 202, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 203, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 204, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.99, max: 23)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 206, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11, max: 23)
#
# Run: 207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.01, max: 23)
#
# Run: 208, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.04, max: 23)
#
# Run: 209, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.03, max: 23)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.03, max: 23)
#
# Run: 211, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.01, max: 23)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.01, max: 23)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.01, max: 23)
#
# Run: 214, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11, max: 23)
#
# Run: 215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.99, max: 23)
#
# Run: 216, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 217, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 219, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 220, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 221, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 222, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.95, max: 23)
#
# Run: 223, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.94, max: 23)
#
# Run: 224, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.95, max: 23)
#
# Run: 225, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.94, max: 23)
#
# Run: 226, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 227, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11, max: 23)
#
# Run: 228, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.99, max: 23)
#
# Run: 229, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 230, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 231, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 232, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 233, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 234, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.99, max: 23)
#
# Run: 235, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.99, max: 23)
#
# Run: 236, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.01, max: 23)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11, max: 23)
#
# Run: 238, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11, max: 23)
#
# Run: 239, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 240, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.93, max: 23)
#
# Run: 241, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.95, max: 23)
#
# Run: 242, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 243, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.95, max: 23)
#
# Run: 244, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.97, max: 23)
#
# Run: 245, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.98, max: 23)
#
# Run: 246, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 247, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.92, max: 23)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.9, max: 23)
#
# Run: 249, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.84, max: 23)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.72, max: 20)
#
# Run: 251, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.75, max: 20)
#
# Run: 252, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.75, max: 20)
#
# Run: 253, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.74, max: 20)
#
# Run: 254, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.74, max: 20)
#
# Run: 255, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.75, max: 20)
#
# Run: 256, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.74, max: 20)
#
# Run: 257, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.73, max: 20)
#
# Run: 258, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.73, max: 20)
#
# Run: 259, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.72, max: 20)
#
# Run: 260, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.71, max: 20)
#
# Run: 261, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.74, max: 20)
#
# Run: 262, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.74, max: 20)
#
# Run: 263, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.71, max: 20)
#
# Run: 264, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.64, max: 20)
#
# Run: 265, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.58, max: 20)
#
# Run: 266, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.54, max: 20)
#
# Run: 267, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.43, max: 20)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.38, max: 20)
#
# Run: 269, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.3, max: 20)
#
# Run: 270, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.24, max: 20)
#
# Run: 271, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.17, max: 20)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.07, max: 18)
#
# Run: 273, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.01, max: 18)
#
# Run: 274, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.93, max: 15)
#
# Run: 275, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.9, max: 15)
#
# Run: 276, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 9.92, max: 17)
#
# Run: 277, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.87, max: 17)
#
# Run: 278, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.85, max: 17)
#
# Run: 279, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.86, max: 17)
#
# Run: 280, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.83, max: 17)
#
# Run: 281, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.83, max: 17)
#
# Run: 282, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 9.9, max: 17)
#
# Run: 283, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 9.94, max: 17)
#
# Run: 284, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.95, max: 17)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.9, max: 17)
#
# Run: 286, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.89, max: 17)
#
# Run: 287, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.9, max: 17)
#
# Run: 288, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.9, max: 17)
#
# Run: 289, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.9, max: 17)
#
# Run: 290, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.9, max: 17)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.88, max: 17)
#
# Run: 292, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.86, max: 17)
#
# Run: 293, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.85, max: 17)
#
# Run: 294, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.86, max: 17)
#
# Run: 295, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 10.1, max: 34)
# Run: 296, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.08, max: 34)
#
# Run: 297, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.08, max: 34)
#
# Run: 298, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.08, max: 34)
#
# Run: 299, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.07, max: 34)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.07, max: 34)
#
# Run: 301, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.08, max: 34)
#
# Run: 302, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.16, max: 34)
#
# Run: 303, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.19, max: 34)
#
# Run: 304, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.18, max: 34)
#
# Run: 305, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.19, max: 34)
#
# Run: 306, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.21, max: 34)
#
# Run: 307, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.25, max: 34)
#
# Run: 308, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.22, max: 34)
#
# Run: 309, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.22, max: 34)
#
# Run: 310, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.22, max: 34)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.24, max: 34)
#
# Run: 312, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.24, max: 34)
#
# Run: 313, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.24, max: 34)
#
# Run: 314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.23, max: 34)
#
# Run: 315, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.23, max: 34)
#
# Run: 316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.24, max: 34)
#
# Run: 317, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.23, max: 34)
#
# Run: 318, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 10.36, max: 34)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.36, max: 34)
#
# Run: 320, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.37, max: 34)
#
# Run: 321, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.36, max: 34)
#
# Run: 322, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.37, max: 34)
#
# Run: 323, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.36, max: 34)
#
# Run: 324, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.37, max: 34)
#
# Run: 325, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.37, max: 34)
#
# Run: 326, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.4, max: 34)
#
# Run: 327, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.4, max: 34)
#
# Run: 328, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.41, max: 34)
#
# Run: 329, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.41, max: 34)
#
# Run: 330, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.41, max: 34)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-670e42b3b2b7> in cartpole()
#      87                 score_logger.add_score(step, run)
#      88                 break
# ---> 89             dqn_solver.experience_replay()
#      90
#
# <ipython-input-3-670e42b3b2b7> in experience_replay(self)
#      54             q_update = reward
#      55             if not terminal:
# ---> 56                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      57             q_values = self.model.predict(state)
#      58             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# The Cartpole game is a simple game where you control a block that is holding a stick vertically. The goal of this game is to keep the stick upright by adjusting the base block from left to right. We can apply our reinforcement learning algorithm to this game and we see how the results played out above. Using the algorithm, the agent learns from experience how to balance the pole better and better with each iteration. The goal for the agent is to keep the stick balanced as long as possible. The different states are either move left, move right, or stationary. The algorithm used is a Q-learning reinforcement algorithm that learns from each iteration to achieve the highest score. This is called experience replay, where it takes the past iterations to achieve the best overall result. We have to use whats called a discount factor in this  algorithm as well to keep it from getting stuck in a continuous loop of the same iterations. This discount factor tell the algorithm how much it should depend on past information, and how much guessing it should do as well. But, this means that results will be both better and worse for each iteration. Since each iteration is saved and remembered, the longer the algorithm runs, the more memory it takes. This is why using a neural network is so effecient. It helps with organizing memory to only remember the most effecient runs, to maximize production results.
#
# As you can see from the first run, it took 303 runs to finish processing, and solved it in 203. This is relatively fast and it achieved the highest result quickly. In the next block, I adjusted the learning rate from 0.001 to 0.01. This made the algorithm work much slower and I eventually had to manually exit the program. The next change I made was to the Gamma value, which I changed from 0.95, to 0.5. This time the algorithm worked much faster for each iteration, but the result did not vary very much. Eventually, I manually stopped the program after about 1500 iterations because the results had not changed very much at all. For the last change, I modified the value of exploration decay from .995 to .605. Again, the algorithm worked much faster for each iteration, but the values we changing at a better pace. The results did have a bigger variation however. For example, one iteration has a score of 17, and the very next one had a score of 155. After about 200 iteration the algorithm seemed to get stuck and only produce scores around 10, so I stopped it.
#
# Sources:
# Surma, G. (2021, October 13). Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
